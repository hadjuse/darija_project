# %%
# !pip install soundfile librosa
# Out:
# Requirement already satisfied: soundfile in ./.miniconda3/lib/python3.13/site-packages (0.13.1)
# Requirement already satisfied: librosa in ./.miniconda3/lib/python3.13/site-packages (0.11.0)
# Requirement already satisfied: cffi>=1.0 in ./.miniconda3/lib/python3.13/site-packages (from soundfile) (2.0.0)
# Requirement already satisfied: numpy in ./.miniconda3/lib/python3.13/site-packages (from soundfile) (2.4.4)
# Requirement already satisfied: audioread>=2.1.9 in ./.miniconda3/lib/python3.13/site-packages (from librosa) (3.1.0)
# Requirement already satisfied: numba>=0.51.0 in ./.miniconda3/lib/python3.13/site-packages (from librosa) (0.65.1)
# Requirement already satisfied: scipy>=1.6.0 in ./.miniconda3/lib/python3.13/site-packages (from librosa) (1.17.1)
# Requirement already satisfied: scikit-learn>=1.1.0 in ./.miniconda3/lib/python3.13/site-packages (from librosa) (1.8.0)
# Requirement already satisfied: joblib>=1.0 in ./.miniconda3/lib/python3.13/site-packages (from librosa) (1.5.3)
# Requirement already satisfied: decorator>=4.3.0 in ./.miniconda3/lib/python3.13/site-packages (from librosa) (5.2.1)
# Requirement already satisfied: pooch>=1.1 in ./.miniconda3/lib/python3.13/site-packages (from librosa) (1.9.0)
# Requirement already satisfied: soxr>=0.3.2 in ./.miniconda3/lib/python3.13/site-packages (from librosa) (1.1.0)
# Requirement already satisfied: typing_extensions>=4.1.1 in ./.miniconda3/lib/python3.13/site-packages (from librosa) (4.15.0)
# Requirement already satisfied: lazy_loader>=0.1 in ./.miniconda3/lib/python3.13/site-packages (from librosa) (0.5)
# Requirement already satisfied: msgpack>=1.0 in ./.miniconda3/lib/python3.13/site-packages (from librosa) (1.1.1)
# Requirement already satisfied: standard-aifc in ./.miniconda3/lib/python3.13/site-packages (from librosa) (3.13.0)
# Requirement already satisfied: standard-sunau in ./.miniconda3/lib/python3.13/site-packages (from librosa) (3.13.0)
# Requirement already satisfied: pycparser in ./.miniconda3/lib/python3.13/site-packages (from cffi>=1.0->soundfile) (2.23)
# Requirement already satisfied: packaging in ./.miniconda3/lib/python3.13/site-packages (from lazy_loader>=0.1->librosa) (25.0)
# Requirement already satisfied: llvmlite<0.48,>=0.47.0dev0 in ./.miniconda3/lib/python3.13/site-packages (from numba>=0.51.0->librosa) (0.47.0)
# Requirement already satisfied: platformdirs>=2.5.0 in ./.miniconda3/lib/python3.13/site-packages (from pooch>=1.1->librosa) (4.5.0)
# Requirement already satisfied: requests>=2.19.0 in ./.miniconda3/lib/python3.13/site-packages (from pooch>=1.1->librosa) (2.32.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in ./.miniconda3/lib/python3.13/site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in ./.miniconda3/lib/python3.13/site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./.miniconda3/lib/python3.13/site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in ./.miniconda3/lib/python3.13/site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (2026.1.4)
# Requirement already satisfied: threadpoolctl>=3.2.0 in ./.miniconda3/lib/python3.13/site-packages (from scikit-learn>=1.1.0->librosa) (3.6.0)
# Requirement already satisfied: standard-chunk in ./.miniconda3/lib/python3.13/site-packages (from standard-aifc->librosa) (3.13.0)
# Requirement already satisfied: audioop-lts in ./.miniconda3/lib/python3.13/site-packages (from standard-aifc->librosa) (0.2.2)

# %%
# On nettoie tout ce qui a pu être installé à moitié
# !pip uninstall -y torch torchvision torchaudio torchcodec

# On installe la version CUDA 12.4 (parfaitement compatible avec votre machine et Python 3.13)
# !pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu124

# On remet torchcodec
# !pip install torchcodec
# Out:
# Found existing installation: torch 2.6.0+cu124
# Uninstalling torch-2.6.0+cu124:
#   Successfully uninstalled torch-2.6.0+cu124
# Found existing installation: torchvision 0.21.0+cu124
# Uninstalling torchvision-0.21.0+cu124:
#   Successfully uninstalled torchvision-0.21.0+cu124
# Found existing installation: torchaudio 2.6.0+cu124
# Uninstalling torchaudio-2.6.0+cu124:
#   Successfully uninstalled torchaudio-2.6.0+cu124
# Found existing installation: torchcodec 0.11.1
# Uninstalling torchcodec-0.11.1:
#   Successfully uninstalled torchcodec-0.11.1
# Looking in indexes: https://download.pytorch.org/whl/cu124
# Collecting torch
#   Using cached torch-2.6.0%2Bcu124-cp313-cp313-linux_x86_64.whl.metadata (28 kB)
# Collecting torchvision
#   Using cached torchvision-0.21.0%2Bcu124-cp313-cp313-linux_x86_64.whl.metadata (6.1 kB)
# Collecting torchaudio
#   Using cached torchaudio-2.6.0%2Bcu124-cp313-cp313-linux_x86_64.whl.metadata (6.6 kB)
# Requirement already satisfied: filelock in ./.miniconda3/lib/python3.13/site-packages (from torch) (3.29.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in ./.miniconda3/lib/python3.13/site-packages (from torch) (4.15.0)
# Requirement already satisfied: networkx in ./.miniconda3/lib/python3.13/site-packages (from torch) (3.6.1)
# Requirement already satisfied: jinja2 in ./.miniconda3/lib/python3.13/site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in ./.miniconda3/lib/python3.13/site-packages (from torch) (2026.4.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in ./.miniconda3/lib/python3.13/site-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in ./.miniconda3/lib/python3.13/site-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in ./.miniconda3/lib/python3.13/site-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in ./.miniconda3/lib/python3.13/site-packages (from torch) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in ./.miniconda3/lib/python3.13/site-packages (from torch) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in ./.miniconda3/lib/python3.13/site-packages (from torch) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in ./.miniconda3/lib/python3.13/site-packages (from torch) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in ./.miniconda3/lib/python3.13/site-packages (from torch) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in ./.miniconda3/lib/python3.13/site-packages (from torch) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in ./.miniconda3/lib/python3.13/site-packages (from torch) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in ./.miniconda3/lib/python3.13/site-packages (from torch) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in ./.miniconda3/lib/python3.13/site-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in ./.miniconda3/lib/python3.13/site-packages (from torch) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in ./.miniconda3/lib/python3.13/site-packages (from torch) (3.2.0)
# Requirement already satisfied: setuptools in ./.miniconda3/lib/python3.13/site-packages (from torch) (80.10.2)
# Requirement already satisfied: sympy==1.13.1 in ./.miniconda3/lib/python3.13/site-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in ./.miniconda3/lib/python3.13/site-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: numpy in ./.miniconda3/lib/python3.13/site-packages (from torchvision) (2.4.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in ./.miniconda3/lib/python3.13/site-packages (from torchvision) (12.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in ./.miniconda3/lib/python3.13/site-packages (from jinja2->torch) (3.0.3)
# Using cached torch-2.6.0%2Bcu124-cp313-cp313-linux_x86_64.whl (768.4 MB)
# Using cached torchvision-0.21.0%2Bcu124-cp313-cp313-linux_x86_64.whl (7.3 MB)
# Using cached torchaudio-2.6.0%2Bcu124-cp313-cp313-linux_x86_64.whl (3.4 MB)
# Installing collected packages: torch, torchvision, torchaudio
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/3 [torch]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/3 [torch]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/3 [torch]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/3 [torch]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/3 [torch]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/3 [torch]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/3 [torch]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/3 [torch]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/3 [torch]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/3 [torch]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/3 [torch]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/3 [torch]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/3 [torch]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/3 [torch]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/3 [torch]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/3 [torch]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/3 [torch]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/3 [torch]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/3 [torch]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/3 [torch]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/3 [torch]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/3 [torch]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/3 [torch]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/3 [torch]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/3 [torch]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/3 [torch]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/3 [torch]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/3 [torch]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/3 [torch]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/3 [torch]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/3 [torch]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/3 [torch]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/3 [torch]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/3 [torch]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/3 [torch]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/3 [torch]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/3 [torch]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/3 [torch]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/3 [torch]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/3 [torch]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/3 [torch]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/3 [torch]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/3 [torch]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/3 [torch]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/3 [torch]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/3 [torch]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/3 [torch]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/3 [torch]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/3 [torch]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/3 [torch]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/3 [torch]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/3 [torch]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/3 [torch]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/3 [torch]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/3 [torch]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/3 [torch]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/3 [torch]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/3 [torch]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/3 [torch]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/3 [torch]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/3 [torch]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/3 [torch]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/3 [torch]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/3 [torch]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/3 [torch]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/3 [torch]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/3 [torch]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/3 [torch]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/3 [torch]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/3 [torch]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/3 [torch]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/3 [torch]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/3 [torch]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/3 [torch]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/3 [torch]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/3 [torch]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/3 [torch]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/3 [torch]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/3 [torch]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/3 [torch]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/3 [torch]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/3 [torch]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/3 [torch]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/3 [torch]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/3 [torch]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/3 [torch]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/3 [torch]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/3 [torch]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/3 [torch]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/3 [torch]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/3 [torch]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/3 [torch]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/3 [torch]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/3 [torch]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/3 [torch]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/3 [torch]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/3 [torch]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/3 [torch]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/3 [torch]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/3 [torch]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/3 [torch]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/3 [torch]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/3 [torch]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/3 [torch]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/3 [torch]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/3 [torch]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/3 [torch]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/3 [torch]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/3 [torch]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/3 [torch]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/3 [torch]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/3 [torch]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/3 [torch]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/3 [torch]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/3 [torch]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/3 [torch]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/3 [torch]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/3 [torch]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/3 [torch]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/3 [torch]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/3 [torch]
#    ━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━ 1/3 [torchvision]
#    ━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━ 1/3 [torchvision]
#    ━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━ 1/3 [torchvision]
#    ━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━ 1/3 [torchvision]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━━━━━━━━━ 2/3 [torchaudio]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━━━━━━━━━ 2/3 [torchaudio]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━━━━━━━━━ 2/3 [torchaudio]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3/3 [torchaudio]
# Successfully installed torch-2.6.0+cu124 torchaudio-2.6.0+cu124 torchvision-0.21.0+cu124
# Collecting torchcodec
#   Using cached torchcodec-0.11.1-cp313-cp313-manylinux_2_28_x86_64.whl.metadata (11 kB)
# Using cached torchcodec-0.11.1-cp313-cp313-manylinux_2_28_x86_64.whl (2.3 MB)
# Installing collected packages: torchcodec
# Successfully installed torchcodec-0.11.1

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import soundfile as sf
import torch
import librosa
import librosa.display
from tqdm.auto import tqdm

# %%
# !nvidia-smi
# Out:
# Sat May  9 23:52:15 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.90.07              Driver Version: 550.90.07      CUDA Version: 12.8     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla V100S-PCIE-32GB          On  |   00000000:00:07.0 Off |                    0 |
# | N/A   35C    P0             26W /  250W |       1MiB /  32768MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
import torch
print(torch.__version__)
print(torch.cuda.is_available())
print(torch.cuda.get_device_name(0))
# Out:
# 2.6.0+cu124
# True
# Tesla V100S-PCIE-32GB

# %%
# !unzip DiffWave_Project.zip
# Out:
# Archive:  DiffWave_Project.zip
#   inflating: DiffWave_Project/data_preprocessed/mels/12733.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12726.npy
#   inflating: DiffWave_Project/data_preprocessed/summary.json
#   inflating: DiffWave_Project/data_preprocessed/mels/12741.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12734.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12725.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12728.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12736.npy
#   inflating: DiffWave_Project/data_preprocessed/test.csv
#   inflating: DiffWave_Project/data_preprocessed/mels/12720.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12730.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12723.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12739.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12724.npy
#   inflating: DiffWave_Project/data_preprocessed/val.csv
#   inflating: DiffWave_Project/data_preprocessed/mels/12737.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12718.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12719.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12729.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12731.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12738.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12742.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12740.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12722.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12727.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12732.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12735.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12721.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12717.npy
#   inflating: DiffWave_Project/data_preprocessed/eda_male.png
#   inflating: DiffWave_Project/data_preprocessed/sample_mels_per_speaker.png
#   inflating: DiffWave_Project/data_preprocessed/train.csv
#   inflating: DiffWave_Project/data_preprocessed/mels/12715.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12701.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12710.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12693.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12709.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12708.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12687.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12692.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12697.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12712.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12702.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12703.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12700.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12707.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12699.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12690.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12711.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12714.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12713.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12689.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12698.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12691.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12706.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12694.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12696.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12704.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12695.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12686.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12705.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12688.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12685.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12716.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12675.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12658.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12683.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12677.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12682.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12679.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12684.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12680.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12665.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12674.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12678.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12671.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12656.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12668.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12664.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12667.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12681.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12669.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12660.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12653.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12666.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12662.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12673.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12672.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12661.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12663.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12659.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12676.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12657.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12654.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12655.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12670.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12652.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12651.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12640.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12648.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12642.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12646.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12635.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12644.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12645.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12649.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12638.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12639.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12641.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12643.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12636.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12629.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12637.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12627.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12634.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12647.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12625.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12631.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12628.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12632.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12650.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12630.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12626.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12624.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12623.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12621.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12633.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12622.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12619.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12620.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12608.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12618.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12609.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12610.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12611.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12616.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12605.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12612.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12607.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12600.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12594.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12601.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12613.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12604.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12599.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12596.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12615.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12603.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12595.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12614.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12597.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12602.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12591.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12606.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12598.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12617.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12593.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12590.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12582.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12592.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12589.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12577.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12587.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12573.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12568.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12566.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12586.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12564.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12571.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12574.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12572.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12562.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12583.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12575.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12585.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12569.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12584.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12588.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12567.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12578.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12576.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12563.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12580.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12570.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12565.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12558.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12581.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12579.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12559.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12561.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12556.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12560.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12553.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12554.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12552.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12557.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12546.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12543.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12549.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12548.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12550.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12531.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12545.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12542.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12539.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12533.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12536.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12537.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12555.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12534.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12544.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12541.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12547.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12528.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12529.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12530.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12525.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12535.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12551.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12538.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12532.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12540.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12524.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12527.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12519.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12522.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12515.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12517.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12521.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12520.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12509.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12526.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12518.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12494.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12511.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12508.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12510.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12506.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12516.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12502.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12514.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12507.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12512.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12523.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12499.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12513.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12500.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12496.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12505.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12501.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12503.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12495.npy
#   inflating: DiffWave_Project/data_preprocessed/wavs/12737.wav
#   inflating: DiffWave_Project/data_preprocessed/mels/12498.npy
#   inflating: DiffWave_Project/data_preprocessed/wavs/12739.wav
#   inflating: DiffWave_Project/data_preprocessed/mels/12504.npy
#   inflating: DiffWave_Project/data_preprocessed/wavs/12742.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12741.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12734.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12736.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12738.wav
#   inflating: DiffWave_Project/data_preprocessed/mels/12493.npy
#   inflating: DiffWave_Project/data_preprocessed/wavs/12730.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12732.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12726.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12722.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12740.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12728.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12733.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12727.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12723.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12714.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12735.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12724.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12731.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12718.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12719.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12717.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12721.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12710.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12713.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12707.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12700.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12715.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12704.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12729.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12711.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12720.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12716.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12708.wav
#   inflating: DiffWave_Project/data_preprocessed/mels/12497.npy
#   inflating: DiffWave_Project/data_preprocessed/wavs/12725.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12705.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12701.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12702.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12709.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12699.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12706.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12698.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12696.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12703.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12697.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12712.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12695.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12694.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12693.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12691.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12685.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12671.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12686.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12688.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12687.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12681.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12673.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12679.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12689.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12683.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12664.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12675.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12690.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12672.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12668.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12692.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12678.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12680.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12665.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12666.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12667.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12674.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12682.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12676.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12677.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12669.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12670.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12684.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12663.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12662.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12658.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12660.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12656.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12657.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12659.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12655.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12644.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12649.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12653.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12651.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12646.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12654.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12643.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12648.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12639.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12647.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12645.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12652.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12641.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12640.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12638.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12661.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12650.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12635.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12636.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12637.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12642.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12632.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12633.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12631.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12624.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12630.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12622.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12614.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12626.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12619.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12628.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12629.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12623.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12634.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12620.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12618.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12621.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12617.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12625.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12616.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12613.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12602.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12627.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12612.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12609.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12606.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12615.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12599.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12603.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12605.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12590.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12610.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12608.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12611.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12607.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12598.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12604.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12600.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12589.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12587.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12593.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12594.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12601.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12595.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12584.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12579.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12596.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12597.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12592.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12583.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12585.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12591.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12581.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12572.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12588.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12580.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12574.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12576.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12569.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12568.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12578.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12577.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12575.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12571.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12582.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12573.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12565.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12586.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12559.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12566.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12562.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12567.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12563.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12564.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12560.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12556.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12553.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12570.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12558.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12554.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12557.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12555.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12543.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12541.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12545.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12540.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12550.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12549.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12552.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12544.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12542.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12548.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12561.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12410.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12551.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12539.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12409.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12547.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12546.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12405.wav
#   inflating: DiffWave_Project/data_preprocessed/mels/12367.npy
#   inflating: DiffWave_Project/data_preprocessed/wavs/12407.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12537.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12538.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12403.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12406.wav
#   inflating: DiffWave_Project/data_preprocessed/mels/12366.npy
#   inflating: DiffWave_Project/data_preprocessed/wavs/12408.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12536.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12404.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12402.wav
#   inflating: DiffWave_Project/data_preprocessed/mels/12249.npy
#   inflating: DiffWave_Project/data_preprocessed/wavs/12364.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12327.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12365.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12531.wav
#   inflating: DiffWave_Project/data_preprocessed/mels/12247.npy
#   inflating: DiffWave_Project/data_preprocessed/wavs/12535.wav
#   inflating: DiffWave_Project/data_preprocessed/mels/12322.npy
#   inflating: DiffWave_Project/data_preprocessed/wavs/12362.wav
#   inflating: DiffWave_Project/data_preprocessed/mels/12286.npy
#   inflating: DiffWave_Project/data_preprocessed/wavs/12322.wav
#   inflating: DiffWave_Project/data_preprocessed/mels/12467.npy
#   inflating: DiffWave_Project/data_preprocessed/wavs/12534.wav
#   inflating: DiffWave_Project/data_preprocessed/mels/12248.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12323.npy
#   inflating: DiffWave_Project/data_preprocessed/wavs/12532.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12325.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12328.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12401.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12324.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12533.wav
#   inflating: DiffWave_Project/data_preprocessed/mels/12285.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12466.npy
#   inflating: DiffWave_Project/data_preprocessed/wavs/12326.wav
#   inflating: DiffWave_Project/data_preprocessed/mels/12400.npy
#   inflating: DiffWave_Project/data_preprocessed/wavs/12530.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12400.wav
#   inflating: DiffWave_Project/data_preprocessed/mels/12284.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12246.npy
#   inflating: DiffWave_Project/data_preprocessed/wavs/12363.wav
#   inflating: DiffWave_Project/data_preprocessed/mels/12365.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12399.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12364.npy
#   inflating: DiffWave_Project/data_preprocessed/wavs/12323.wav
#   inflating: DiffWave_Project/data_preprocessed/mels/12283.npy
#   inflating: DiffWave_Project/data_preprocessed/wavs/12319.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12359.wav
#   inflating: DiffWave_Project/data_preprocessed/mels/12401.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12363.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12433.npy
#   inflating: DiffWave_Project/data_preprocessed/wavs/12321.wav
#   inflating: DiffWave_Project/data_preprocessed/mels/12465.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12320.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12321.npy
#   inflating: DiffWave_Project/data_preprocessed/wavs/12360.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12361.wav
#   inflating: DiffWave_Project/data_preprocessed/mels/12464.npy
#   inflating: DiffWave_Project/data_preprocessed/wavs/12287.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12399.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12286.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12529.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12320.wav
#   inflating: DiffWave_Project/data_preprocessed/mels/12463.npy
#   inflating: DiffWave_Project/data_preprocessed/wavs/12285.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12528.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12284.wav
#   inflating: DiffWave_Project/data_preprocessed/mels/12398.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12362.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12244.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12319.npy
#   inflating: DiffWave_Project/data_preprocessed/wavs/12358.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12442.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12318.wav
#   inflating: DiffWave_Project/data_preprocessed/mels/12245.npy
#   inflating: DiffWave_Project/data_preprocessed/wavs/12283.wav
#   inflating: DiffWave_Project/data_preprocessed/mels/12282.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12318.npy
#   inflating: DiffWave_Project/data_preprocessed/wavs/12527.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12497.wav
#   inflating: DiffWave_Project/data_preprocessed/mels/12462.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12432.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12361.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12397.npy
#   inflating: DiffWave_Project/data_preprocessed/wavs/12441.wav
#   inflating: DiffWave_Project/data_preprocessed/mels/12360.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12431.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12281.npy
#   inflating: DiffWave_Project/data_preprocessed/wavs/12398.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12282.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12396.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12397.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12357.wav
#   inflating: DiffWave_Project/data_preprocessed/mels/12243.npy
#   inflating: DiffWave_Project/data_preprocessed/wavs/12251.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12317.wav
#   inflating: DiffWave_Project/data_preprocessed/mels/12317.npy
#   inflating: DiffWave_Project/data_preprocessed/wavs/12440.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12250.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12248.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12247.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12249.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12496.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12439.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12281.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12526.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12492.wav
#   inflating: DiffWave_Project/data_preprocessed/mels/12359.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12396.npy
#   inflating: DiffWave_Project/data_preprocessed/wavs/12495.wav
#   inflating: DiffWave_Project/data_preprocessed/mels/12280.npy
#   inflating: DiffWave_Project/data_preprocessed/wavs/12246.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12491.wav
#   inflating: DiffWave_Project/data_preprocessed/mels/12395.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12430.npy
#   inflating: DiffWave_Project/data_preprocessed/wavs/12245.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12280.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12395.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12394.wav
#   inflating: DiffWave_Project/data_preprocessed/mels/12461.npy
#   inflating: DiffWave_Project/data_preprocessed/wavs/12525.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12438.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12316.wav
#   inflating: DiffWave_Project/data_preprocessed/mels/12279.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12460.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12358.npy
#   inflating: DiffWave_Project/data_preprocessed/wavs/12355.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12524.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12356.wav
#   inflating: DiffWave_Project/data_preprocessed/mels/12215.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12213.npy
#   inflating: DiffWave_Project/data_preprocessed/wavs/12315.wav
#   inflating: DiffWave_Project/data_preprocessed/mels/12214.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12208.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12316.npy
#   inflating: DiffWave_Project/data_preprocessed/wavs/12243.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12279.wav
#   inflating: DiffWave_Project/data_preprocessed/mels/12216.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12212.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12211.npy
#   inflating: DiffWave_Project/data_preprocessed/wavs/12244.wav
#   inflating: DiffWave_Project/data_preprocessed/mels/12210.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12315.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12429.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12209.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12459.npy
#   inflating: DiffWave_Project/data_preprocessed/wavs/12314.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12436.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12494.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12354.wav
#   inflating: DiffWave_Project/data_preprocessed/mels/12394.npy
#   inflating: DiffWave_Project/data_preprocessed/wavs/12437.wav
#   inflating: DiffWave_Project/data_preprocessed/mels/12356.npy
#   inflating: DiffWave_Project/data_preprocessed/wavs/12278.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12490.wav
#   inflating: DiffWave_Project/data_preprocessed/mels/12242.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12357.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12207.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12278.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12313.npy
#   inflating: DiffWave_Project/data_preprocessed/wavs/12493.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12353.wav
#   inflating: DiffWave_Project/data_preprocessed/mels/12355.npy
#   inflating: DiffWave_Project/data_preprocessed/wavs/12523.wav
#   inflating: DiffWave_Project/data_preprocessed/mels/12427.npy
#   inflating: DiffWave_Project/data_preprocessed/wavs/12393.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12522.wav
#   inflating: DiffWave_Project/data_preprocessed/mels/12428.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12314.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12177.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12393.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12241.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12277.npy
#   inflating: DiffWave_Project/data_preprocessed/wavs/12277.wav
#   inflating: DiffWave_Project/data_preprocessed/mels/12176.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12175.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12458.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12179.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12172.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12173.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12170.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12171.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12169.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12167.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12178.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12174.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12206.npy
#   inflating: DiffWave_Project/data_preprocessed/wavs/12313.wav
#   inflating: DiffWave_Project/data_preprocessed/mels/12312.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12492.npy
#   inflating: DiffWave_Project/data_preprocessed/wavs/12392.wav
#   inflating: DiffWave_Project/data_preprocessed/mels/12165.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12166.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12168.npy
#   inflating: DiffWave_Project/data_preprocessed/wavs/12488.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12435.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12489.wav
#   inflating: DiffWave_Project/data_preprocessed/mels/12354.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12311.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12457.npy
#   inflating: DiffWave_Project/data_preprocessed/wavs/12352.wav
#   inflating: DiffWave_Project/data_preprocessed/mels/12392.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12426.npy
#   inflating: DiffWave_Project/data_preprocessed/wavs/12521.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12391.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12312.wav
#   inflating: DiffWave_Project/data_preprocessed/mels/12353.npy
#   inflating: DiffWave_Project/data_preprocessed/wavs/12276.wav
#   inflating: DiffWave_Project/data_preprocessed/mels/12134.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12240.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12205.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12276.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12139.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12425.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12164.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12136.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12138.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12491.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12131.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12133.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12135.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12137.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12275.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12128.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12140.npy
#   inflating: DiffWave_Project/data_preprocessed/wavs/12487.wav
#   inflating: DiffWave_Project/data_preprocessed/mels/12132.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12130.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12456.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12127.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12490.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12239.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12129.npy
#   inflating: DiffWave_Project/data_preprocessed/wavs/12390.wav
#   inflating: DiffWave_Project/data_preprocessed/mels/12352.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12424.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12391.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12204.npy
#   inflating: DiffWave_Project/data_preprocessed/wavs/12434.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12351.wav
#   inflating: DiffWave_Project/data_preprocessed/mels/12390.npy
#   inflating: DiffWave_Project/data_preprocessed/wavs/12486.wav
#   inflating: DiffWave_Project/data_preprocessed/mels/12101.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12092.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12093.npy
#   inflating: DiffWave_Project/data_preprocessed/wavs/12520.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12275.wav
#   inflating: DiffWave_Project/data_preprocessed/mels/12310.npy
#   inflating: DiffWave_Project/data_preprocessed/wavs/12519.wav
#   inflating: DiffWave_Project/data_preprocessed/mels/12100.npy
#   inflating: DiffWave_Project/data_preprocessed/wavs/12311.wav
#   inflating: DiffWave_Project/data_preprocessed/mels/12099.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12274.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12097.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12163.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12098.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12096.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12094.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12090.npy
#   inflating: DiffWave_Project/data_preprocessed/wavs/12433.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12350.wav
#   inflating: DiffWave_Project/data_preprocessed/mels/12091.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12089.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12095.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12238.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12351.npy
#   inflating: DiffWave_Project/data_preprocessed/wavs/12274.wav
#   inflating: DiffWave_Project/data_preprocessed/mels/12203.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12162.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12455.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12126.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12088.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/12389.npy
#   inflating: DiffWave_Project/data_preprocessed/wavs/12389.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12310.wav
# ...
#   inflating: DiffWave_Project/data_preprocessed/mels/02968.npy
#   inflating: DiffWave_Project/data_preprocessed/wavs/09217.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/11692.wav
#   inflating: DiffWave_Project/data_preprocessed/mels/12141.npy
#   inflating: DiffWave_Project/data_preprocessed/wavs/11942.wav
#   inflating: DiffWave_Project/data_preprocessed/mels/10808.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/10088.npy
#   inflating: DiffWave_Project/data_preprocessed/wavs/01847.wav
#   inflating: DiffWave_Project/data_preprocessed/mels/10072.npy
#   inflating: DiffWave_Project/data_preprocessed/wavs/03175.wav
#   inflating: DiffWave_Project/data_preprocessed/mels/01117.npy
#   inflating: DiffWave_Project/data_preprocessed/wavs/02763.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/02905.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/01103.wav
#   inflating: DiffWave_Project/data_preprocessed/mels/06907.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/01236.npy
#   inflating: DiffWave_Project/data_preprocessed/wavs/01461.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/10187.wav
#   inflating: DiffWave_Project/data_preprocessed/mels/02787.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/03748.npy
#   inflating: DiffWave_Project/data_preprocessed/wavs/01063.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/01814.wav
#   inflating: DiffWave_Project/data_preprocessed/mels/02895.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/01350.npy
#   inflating: DiffWave_Project/data_preprocessed/wavs/02870.wav
#   inflating: DiffWave_Project/data_preprocessed/mels/09242.npy
#   inflating: DiffWave_Project/data_preprocessed/wavs/01384.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/01176.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/01254.wav
#   inflating: DiffWave_Project/data_preprocessed/mels/01925.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/01781.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/06289.npy
#   inflating: DiffWave_Project/data_preprocessed/wavs/06803.wav
#   inflating: DiffWave_Project/data_preprocessed/mels/09101.npy
#   inflating: DiffWave_Project/data_preprocessed/wavs/10988.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/02833.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/01994.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/09009.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/09816.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/01504.wav
#   inflating: DiffWave_Project/data_preprocessed/mels/09035.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/06256.npy
#   inflating: DiffWave_Project/data_preprocessed/wavs/10041.wav
#   inflating: DiffWave_Project/data_preprocessed/mels/06133.npy
#   inflating: DiffWave_Project/data_preprocessed/wavs/12288.wav
#   inflating: DiffWave_Project/data_preprocessed/mels/06976.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/06670.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/04983.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/03029.npy
#   inflating: DiffWave_Project/data_preprocessed/wavs/09852.wav
#   inflating: DiffWave_Project/data_preprocessed/mels/10197.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/09890.npy
#   inflating: DiffWave_Project/data_preprocessed/wavs/03709.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/03355.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/06622.wav
#   inflating: DiffWave_Project/data_preprocessed/mels/09632.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/02995.npy
#   inflating: DiffWave_Project/data_preprocessed/wavs/09274.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/03283.wav
#   inflating: DiffWave_Project/data_preprocessed/mels/09260.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/10876.npy
#   inflating: DiffWave_Project/data_preprocessed/wavs/03676.wav
#   inflating: DiffWave_Project/data_preprocessed/mels/06359.npy
#   inflating: DiffWave_Project/data_preprocessed/wavs/03567.wav
#   inflating: DiffWave_Project/data_preprocessed/mels/09137.npy
#   inflating: DiffWave_Project/data_preprocessed/wavs/12162.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/03963.wav
#   inflating: DiffWave_Project/data_preprocessed/mels/03529.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/09403.npy
#   inflating: DiffWave_Project/data_preprocessed/wavs/04693.wav
#   inflating: DiffWave_Project/data_preprocessed/mels/09437.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/03668.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/10293.npy
#   inflating: DiffWave_Project/data_preprocessed/wavs/03799.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/03833.wav
#   inflating: DiffWave_Project/data_preprocessed/mels/04737.npy
#   inflating: DiffWave_Project/data_preprocessed/wavs/04375.wav
#   inflating: DiffWave_Project/data_preprocessed/mels/06940.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/09293.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/04324.npy
#   inflating: DiffWave_Project/data_preprocessed/wavs/03742.wav
#   inflating: DiffWave_Project/data_preprocessed/mels/09852.npy
#   inflating: DiffWave_Project/data_preprocessed/wavs/04310.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/09623.wav
#   inflating: DiffWave_Project/data_preprocessed/mels/03171.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/09595.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/04424.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/09558.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/04538.npy
#   inflating: DiffWave_Project/data_preprocessed/wavs/09142.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/09476.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/04661.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/04406.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/06945.wav
#   inflating: DiffWave_Project/data_preprocessed/mels/04994.npy
#   inflating: DiffWave_Project/data_preprocessed/wavs/04438.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/04629.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/10950.wav
#   inflating: DiffWave_Project/data_preprocessed/mels/04887.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/04638.npy
#   inflating: DiffWave_Project/data_preprocessed/wavs/04933.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/10227.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/10151.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/04268.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/06016.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/09960.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/01743.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/06440.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/12202.wav
#   inflating: DiffWave_Project/data_preprocessed/mels/06167.npy
#   inflating: DiffWave_Project/data_preprocessed/wavs/06876.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/10269.wav
#   inflating: DiffWave_Project/data_preprocessed/mels/09476.npy
#   inflating: DiffWave_Project/data_preprocessed/wavs/04563.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/06556.wav
#   inflating: DiffWave_Project/data_preprocessed/mels/10042.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/09815.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/10011.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/06538.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/06702.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/02826.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/02863.npy
#   inflating: DiffWave_Project/data_preprocessed/wavs/01608.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/10078.wav
#   inflating: DiffWave_Project/data_preprocessed/mels/03956.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/06871.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/03783.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/02732.npy
#   inflating: DiffWave_Project/data_preprocessed/wavs/10661.wav
#   inflating: DiffWave_Project/data_preprocessed/mels/06458.npy
#   inflating: DiffWave_Project/data_preprocessed/wavs/01534.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/01214.wav
#   inflating: DiffWave_Project/data_preprocessed/mels/01463.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/01537.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/01316.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/06769.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/01962.npy
#   inflating: DiffWave_Project/data_preprocessed/wavs/06656.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/01142.wav
#   inflating: DiffWave_Project/data_preprocessed/mels/06097.npy
#   inflating: DiffWave_Project/data_preprocessed/wavs/03072.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/04102.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/03140.wav
#   inflating: DiffWave_Project/data_preprocessed/mels/06325.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/06640.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/03602.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/06199.npy
#   inflating: DiffWave_Project/data_preprocessed/wavs/09040.wav
#   inflating: DiffWave_Project/data_preprocessed/mels/03308.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/04947.npy
#   inflating: DiffWave_Project/data_preprocessed/wavs/03641.wav
#   inflating: DiffWave_Project/data_preprocessed/mels/06064.npy
#   inflating: DiffWave_Project/data_preprocessed/wavs/03506.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/02798.wav
#   inflating: DiffWave_Project/data_preprocessed/mels/06604.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/03637.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/04753.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/03409.npy
#   inflating: DiffWave_Project/data_preprocessed/wavs/11800.wav
#   inflating: DiffWave_Project/data_preprocessed/mels/03564.npy
#   inflating: DiffWave_Project/data_preprocessed/wavs/03927.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/04340.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/03533.wav
#   inflating: DiffWave_Project/data_preprocessed/mels/04227.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/04063.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/03925.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/04852.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/04488.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/04784.npy
#   inflating: DiffWave_Project/data_preprocessed/wavs/01310.wav
#   inflating: DiffWave_Project/data_preprocessed/mels/09068.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/04506.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/04292.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/04601.npy
#   inflating: DiffWave_Project/data_preprocessed/wavs/06368.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/04594.wav
#   inflating: DiffWave_Project/data_preprocessed/mels/04819.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/01079.npy
#   inflating: DiffWave_Project/data_preprocessed/wavs/01643.wav
#   inflating: DiffWave_Project/data_preprocessed/mels/02757.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/01710.npy
#   inflating: DiffWave_Project/data_preprocessed/wavs/06842.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/03461.wav
#   inflating: DiffWave_Project/data_preprocessed/mels/03858.npy
#   inflating: DiffWave_Project/data_preprocessed/wavs/09734.wav
#   inflating: DiffWave_Project/data_preprocessed/mels/01393.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/06492.npy
#   inflating: DiffWave_Project/data_preprocessed/wavs/09701.wav
#   inflating: DiffWave_Project/data_preprocessed/mels/04024.npy
#   inflating: DiffWave_Project/data_preprocessed/wavs/01277.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/06690.wav
#   inflating: DiffWave_Project/data_preprocessed/mels/06428.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/06237.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/01634.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/06569.npy
#   inflating: DiffWave_Project/data_preprocessed/wavs/03321.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/03210.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/04135.wav
#   inflating: DiffWave_Project/data_preprocessed/mels/09174.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/03701.npy
#   inflating: DiffWave_Project/data_preprocessed/wavs/06212.wav
#   inflating: DiffWave_Project/data_preprocessed/mels/03734.npy
#   inflating: DiffWave_Project/data_preprocessed/wavs/03001.wav
#   inflating: DiffWave_Project/data_preprocessed/mels/04162.npy
#   inflating: DiffWave_Project/data_preprocessed/wavs/06302.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/04969.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/03249.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/06178.wav
#   inflating: DiffWave_Project/data_preprocessed/mels/04572.npy
#   inflating: DiffWave_Project/data_preprocessed/wavs/04724.wav
#   inflating: DiffWave_Project/data_preprocessed/mels/06738.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/04193.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/03380.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/01429.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/01603.npy
#   inflating: DiffWave_Project/data_preprocessed/wavs/04865.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/06469.wav
#   inflating: DiffWave_Project/data_preprocessed/mels/03472.npy
#   inflating: DiffWave_Project/data_preprocessed/wavs/04500.wav
#   inflating: DiffWave_Project/data_preprocessed/mels/02931.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/01819.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/03276.npy
#   inflating: DiffWave_Project/data_preprocessed/wavs/09108.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/06400.wav
#   inflating: DiffWave_Project/data_preprocessed/mels/03242.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/03994.npy
#   inflating: DiffWave_Project/data_preprocessed/wavs/04201.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/04900.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/04801.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/06774.wav
#   inflating: DiffWave_Project/data_preprocessed/mels/04129.npy
#   inflating: DiffWave_Project/data_preprocessed/wavs/06263.wav
#   inflating: DiffWave_Project/data_preprocessed/mels/04261.npy
#   inflating: DiffWave_Project/data_preprocessed/mels/01275.npy
#   inflating: DiffWave_Project/data_preprocessed/wavs/01713.wav
#   inflating: DiffWave_Project/data_preprocessed/mels/04391.npy
#   inflating: DiffWave_Project/data_preprocessed/wavs/03866.wav
#   inflating: DiffWave_Project/data_preprocessed/mels/04671.npy
#   inflating: DiffWave_Project/data_preprocessed/wavs/03896.wav
#   inflating: DiffWave_Project/data_preprocessed/mels/01197.npy
#   inflating: DiffWave_Project/data_preprocessed/wavs/04166.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/03105.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/03035.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/01025.wav
#   inflating: DiffWave_Project/data_preprocessed/wavs/01427.wav
#   inflating: DiffWave_Project/data_preprocessed/mels/03067.npy

# %%
from pathlib import Path

for path in Path.cwd().rglob("train.csv"):
    print(path)
# Out:
# /workspace/DiffWave_Project/data_preprocessed/train.csv

# %%
from pathlib import Path
import pandas as pd
import json
import numpy as np

# ============================================================
# 1. Chemins principaux
# ============================================================

PROJECT_DIR = Path("/workspace/DiffWave_Project")
DATA_DIR = PROJECT_DIR / "data_preprocessed"

# ============================================================
# 2. Fichiers et dossiers
# ============================================================

TRAIN_CSV = DATA_DIR / "train.csv"
VAL_CSV   = DATA_DIR / "val.csv"
TEST_CSV  = DATA_DIR / "test.csv"
SUMMARY_JSON = DATA_DIR / "summary.json"

WAV_DIR = DATA_DIR / "wavs"
MEL_DIR = DATA_DIR / "mels"

CHECKPOINT_DIR = PROJECT_DIR / "checkpoints"
FIGURES_DIR    = PROJECT_DIR / "figures"
RESULTS_DIR    = PROJECT_DIR / "results"
GENERATED_DIR  = PROJECT_DIR / "generated_audios"

for directory in [CHECKPOINT_DIR, FIGURES_DIR, RESULTS_DIR, GENERATED_DIR]:
    directory.mkdir(parents=True, exist_ok=True)

# ============================================================
# 3. Vérification des chemins
# ============================================================

print("\nVérification des chemins")
print("------------------------")
print("PROJECT_DIR existe :", PROJECT_DIR.exists())
print("DATA_DIR existe    :", DATA_DIR.exists())

print("\nFichiers CSV / JSON")
print("-------------------")
print("train.csv existe   :", TRAIN_CSV.exists())
print("val.csv existe     :", VAL_CSV.exists())
print("test.csv existe    :", TEST_CSV.exists())
print("summary.json existe:", SUMMARY_JSON.exists())

print("\nDossiers audio / Mel")
print("--------------------")
print("wavs existe :", WAV_DIR.exists())
print("mels existe :", MEL_DIR.exists())

print("\nNombre de fichiers")
print("------------------")
print("Nombre de wavs :", len(list(WAV_DIR.glob("*.wav"))) if WAV_DIR.exists() else "dossier absent")
print("Nombre de mels :", len(list(MEL_DIR.glob("*.npy"))) if MEL_DIR.exists() else "dossier absent")

# ============================================================
# 4. Chargement des CSV et du summary
# ============================================================

train_df = pd.read_csv(TRAIN_CSV)
val_df   = pd.read_csv(VAL_CSV)
test_df  = pd.read_csv(TEST_CSV)

with open(SUMMARY_JSON, "r", encoding="utf-8") as f:
    summary = json.load(f)

print("\nSplits chargés")
print("--------------")
print("Train :", train_df.shape)
print("Val   :", val_df.shape)
print("Test  :", test_df.shape)

print("\nRésumé du prétraitement")
print("-----------------------")
print(summary)

display(train_df.head())
display(val_df.head())
display(test_df.head())

# ============================================================
# 5. Test rapide d'un Mel spectrogram
# ============================================================

example_mel_path = Path(train_df.iloc[0]["mel_path"])

if not example_mel_path.exists():
    example_id = str(train_df.iloc[0]["id"]).zfill(5)
    example_mel_path = MEL_DIR / f"{example_id}.npy"

mel = np.load(example_mel_path)

print("\nTest Mel spectrogram")
print("--------------------")
print("Mel path  :", example_mel_path)
print("Mel shape :", mel.shape)
print("Mel min/max :", mel.min(), mel.max())
# Out:
# Vérification des chemins
# ------------------------
# PROJECT_DIR existe : True
# DATA_DIR existe    : True
#
# Fichiers CSV / JSON
# -------------------
# train.csv existe   : True
# val.csv existe     : True
# test.csv existe    : True
# summary.json existe: True
#
# Dossiers audio / Mel
# --------------------
# wavs existe : True
# mels existe : True
#
# Nombre de fichiers
# ------------------
# Nombre de wavs : 8012
# Nombre de mels : 8012
#
# Splits chargés
# --------------
# Train : (6489, 7)
# Val   : (721, 7)
# Test  : (802, 7)
#
# Résumé du prétraitement
# -----------------------
# {'dataset': 'atlasia/DODa-audio-dataset', 'filtre': 'voix masculines (M1, M2, M3)', 'exemples_traites': 8012, 'duree_totale_h': 6.26, 'locuteurs': ['M1', 'M2', 'M3'], 'sample_rate': 22050, 'n_mels': 80, 'n_fft': 1024, 'hop_length': 256, 'splits': {'train': 6489, 'val': 721, 'test': 802}}
#       id speaker         text_latin  \
# 0   9111      M2         ana tsizit
# 1  10284      M1     b Tabi3at l7al
# 2   9520      M2  chokran 3la lkado
# 3  10666      M1           nowanbir
# 4   1462      M3         3lach ana?
#
#                                             wav_path  \
# 0  /content/drive/MyDrive/DiffWave_Project/data_p...
# 1  /content/drive/MyDrive/DiffWave_Project/data_p...
# 2  /content/drive/MyDrive/DiffWave_Project/data_p...
# 3  /content/drive/MyDrive/DiffWave_Project/data_p...
# 4  /content/drive/MyDrive/DiffWave_Project/data_p...
#
#                                             mel_path  duration_s  mel_frames
# 0  /content/drive/MyDrive/DiffWave_Project/data_p...       2.283         197
# 1  /content/drive/MyDrive/DiffWave_Project/data_p...       2.539         219
# 2  /content/drive/MyDrive/DiffWave_Project/data_p...       2.176         188
# 3  /content/drive/MyDrive/DiffWave_Project/data_p...       1.472         127
# 4  /content/drive/MyDrive/DiffWave_Project/data_p...       1.707         148
#       id speaker                                         text_latin  \
# 0   3167      M2                                         ah, drayfa
# 1  12027      M2          achnahowa a7ssen new3 dial chti7 3endek ?
# 2   3269      M2                                         ana katib.
# 3  12728      M1  ghanchouf wach kayna chi reservatio m3a tmenya...
# 4  12316      M2  ana m9tan3a bli 3a2iltna fach kitjm3ou kiweliw...
#
#                                             wav_path  \
# 0  /content/drive/MyDrive/DiffWave_Project/data_p...
# 1  /content/drive/MyDrive/DiffWave_Project/data_p...
# 2  /content/drive/MyDrive/DiffWave_Project/data_p...
# 3  /content/drive/MyDrive/DiffWave_Project/data_p...
# 4  /content/drive/MyDrive/DiffWave_Project/data_p...
#
#                                             mel_path  duration_s  mel_frames
# 0  /content/drive/MyDrive/DiffWave_Project/data_p...       1.643         142
# 1  /content/drive/MyDrive/DiffWave_Project/data_p...       2.709         234
# 2  /content/drive/MyDrive/DiffWave_Project/data_p...       1.771         153
# 3  /content/drive/MyDrive/DiffWave_Project/data_p...       3.648         315
# 4  /content/drive/MyDrive/DiffWave_Project/data_p...       5.525         476
#       id speaker                                 text_latin  \
# 0   3757      M2           walakin nta kan 3ndk jtima3 S3ib
# 1  10384      M1                                    redlbal
# 2   4938      M1      momkin tabghiha 9bal mosi9a dyal rock
# 3  11678      M1  kaystresse mli katchouf nass a5rin ki5niw
# 4   3633      M2  nta katbi3 otchri f achmn naw3 dyal nifT?
#
#                                             wav_path  \
# 0  /content/drive/MyDrive/DiffWave_Project/data_p...
# 1  /content/drive/MyDrive/DiffWave_Project/data_p...
# 2  /content/drive/MyDrive/DiffWave_Project/data_p...
# 3  /content/drive/MyDrive/DiffWave_Project/data_p...
# 4  /content/drive/MyDrive/DiffWave_Project/data_p...
#
#                                             mel_path  duration_s  mel_frames
# 0  /content/drive/MyDrive/DiffWave_Project/data_p...       2.987         258
# 1  /content/drive/MyDrive/DiffWave_Project/data_p...       2.347         203
# 2  /content/drive/MyDrive/DiffWave_Project/data_p...       3.541         306
# 3  /content/drive/MyDrive/DiffWave_Project/data_p...       3.861         333
# 4  /content/drive/MyDrive/DiffWave_Project/data_p...       2.837         245
# Test Mel spectrogram
# --------------------
# Mel path  : /workspace/DiffWave_Project/data_preprocessed/mels/09111.npy
# Mel shape : (80, 197)
# Mel min/max : -11.5 4.9098268

# %%
train_df = pd.read_csv(TRAIN_CSV)
val_df = pd.read_csv(VAL_CSV)
test_df = pd.read_csv(TEST_CSV)

print("Train :", train_df.shape)
print("Val :", val_df.shape)
print("Test :", test_df.shape)

display(train_df.head())
display(val_df.head())
display(test_df.head())
# Out:
# Train : (6489, 7)
# Val : (721, 7)
# Test : (802, 7)
#       id speaker         text_latin  \
# 0   9111      M2         ana tsizit
# 1  10284      M1     b Tabi3at l7al
# 2   9520      M2  chokran 3la lkado
# 3  10666      M1           nowanbir
# 4   1462      M3         3lach ana?
#
#                                             wav_path  \
# 0  /content/drive/MyDrive/DiffWave_Project/data_p...
# 1  /content/drive/MyDrive/DiffWave_Project/data_p...
# 2  /content/drive/MyDrive/DiffWave_Project/data_p...
# 3  /content/drive/MyDrive/DiffWave_Project/data_p...
# 4  /content/drive/MyDrive/DiffWave_Project/data_p...
#
#                                             mel_path  duration_s  mel_frames
# 0  /content/drive/MyDrive/DiffWave_Project/data_p...       2.283         197
# 1  /content/drive/MyDrive/DiffWave_Project/data_p...       2.539         219
# 2  /content/drive/MyDrive/DiffWave_Project/data_p...       2.176         188
# 3  /content/drive/MyDrive/DiffWave_Project/data_p...       1.472         127
# 4  /content/drive/MyDrive/DiffWave_Project/data_p...       1.707         148
#       id speaker                                         text_latin  \
# 0   3167      M2                                         ah, drayfa
# 1  12027      M2          achnahowa a7ssen new3 dial chti7 3endek ?
# 2   3269      M2                                         ana katib.
# 3  12728      M1  ghanchouf wach kayna chi reservatio m3a tmenya...
# 4  12316      M2  ana m9tan3a bli 3a2iltna fach kitjm3ou kiweliw...
#
#                                             wav_path  \
# 0  /content/drive/MyDrive/DiffWave_Project/data_p...
# 1  /content/drive/MyDrive/DiffWave_Project/data_p...
# 2  /content/drive/MyDrive/DiffWave_Project/data_p...
# 3  /content/drive/MyDrive/DiffWave_Project/data_p...
# 4  /content/drive/MyDrive/DiffWave_Project/data_p...
#
#                                             mel_path  duration_s  mel_frames
# 0  /content/drive/MyDrive/DiffWave_Project/data_p...       1.643         142
# 1  /content/drive/MyDrive/DiffWave_Project/data_p...       2.709         234
# 2  /content/drive/MyDrive/DiffWave_Project/data_p...       1.771         153
# 3  /content/drive/MyDrive/DiffWave_Project/data_p...       3.648         315
# 4  /content/drive/MyDrive/DiffWave_Project/data_p...       5.525         476
#       id speaker                                 text_latin  \
# 0   3757      M2           walakin nta kan 3ndk jtima3 S3ib
# 1  10384      M1                                    redlbal
# 2   4938      M1      momkin tabghiha 9bal mosi9a dyal rock
# 3  11678      M1  kaystresse mli katchouf nass a5rin ki5niw
# 4   3633      M2  nta katbi3 otchri f achmn naw3 dyal nifT?
#
#                                             wav_path  \
# 0  /content/drive/MyDrive/DiffWave_Project/data_p...
# 1  /content/drive/MyDrive/DiffWave_Project/data_p...
# 2  /content/drive/MyDrive/DiffWave_Project/data_p...
# 3  /content/drive/MyDrive/DiffWave_Project/data_p...
# 4  /content/drive/MyDrive/DiffWave_Project/data_p...
#
#                                             mel_path  duration_s  mel_frames
# 0  /content/drive/MyDrive/DiffWave_Project/data_p...       2.987         258
# 1  /content/drive/MyDrive/DiffWave_Project/data_p...       2.347         203
# 2  /content/drive/MyDrive/DiffWave_Project/data_p...       3.541         306
# 3  /content/drive/MyDrive/DiffWave_Project/data_p...       3.861         333
# 4  /content/drive/MyDrive/DiffWave_Project/data_p...       2.837         245

# %%
with open(SUMMARY_JSON, "r", encoding="utf-8") as f:
    summary = json.load(f)

summary
# Out:
# {'dataset': 'atlasia/DODa-audio-dataset',
#  'filtre': 'voix masculines (M1, M2, M3)',
#  'exemples_traites': 8012,
#  'duree_totale_h': 6.26,
#  'locuteurs': ['M1', 'M2', 'M3'],
#  'sample_rate': 22050,
#  'n_mels': 80,
#  'n_fft': 1024,
#  'hop_length': 256,
#  'splits': {'train': 6489, 'val': 721, 'test': 802}}

# %%
example_mel_path = Path(train_df.iloc[0]["mel_path"])

# Si le chemin dans le CSV est relatif ou local, on le reconstruit :
if not example_mel_path.exists():
    example_id = str(train_df.iloc[0]["id"]).zfill(5)
    example_mel_path = MEL_DIR / f"{example_id}.npy"

mel = np.load(example_mel_path)

print("Mel path :", example_mel_path)
print("Mel shape :", mel.shape)
print("Mel min/max :", mel.min(), mel.max())
# Out:
# Mel path : /workspace/DiffWave_Project/data_preprocessed/mels/09111.npy
# Mel shape : (80, 197)
# Mel min/max : -11.5 4.9098268

# %% [markdown]
# # Préparation du Dataset PyTorch pour DiffWave
#
# Dans cette partie, on prépare les données pour l'entraînement du modèle DiffWave.
#
# Les fichiers audio prétraités sont au format `.wav`, tandis que les spectrogrammes Mel sont sauvegardés au format `.npy`.
#
# L’objectif est de créer un Dataset PyTorch capable de charger correctement chaque paire :
#
# - audio prétraité ;
# - spectrogramme Mel correspondant.
#
# On vérifiera ensuite que les dimensions sont compatibles avec le modèle DiffWave.

# %%
# !pip install -q git+https://github.com/lmnt-com/diffwave.git

import os
import soundfile as sf
import torch
from torch.utils.data import Dataset, DataLoader

from diffwave.model import DiffWave
from diffwave.params import params

device = "cuda" if torch.cuda.is_available() else "cpu"
print("Device utilisé :", device)
# Out:
# Device utilisé : cuda

# %% [markdown]
# ## Vérification des paramètres DiffWave
#
# On vérifie maintenant les paramètres internes utilisés par l’implémentation DiffWave.
#
# Ils doivent être cohérents avec le prétraitement déjà réalisé, notamment :
#
# - le nombre de bandes Mel ;
# - la taille du hop ;
# - le nombre de frames Mel utilisées pendant l’entraînement.

# %%
print("Paramètres DiffWave chargés :")
print("n_mels :", params.n_mels)
print("n_fft :", params.n_fft)
print("hop_samples :", params.hop_samples)
print("crop_mel_frames :", params.crop_mel_frames)
print("residual_layers :", params.residual_layers)
print("residual_channels :", params.residual_channels)
# Out:
# Paramètres DiffWave chargés :
# n_mels : 80
# n_fft : 1024
# hop_samples : 256
# crop_mel_frames : 62
# residual_layers : 30
# residual_channels : 64

# %% [markdown]
# ## Création du Dataset PyTorch
#
# Le Dataset lit les chemins indiqués dans les fichiers `train.csv` et `val.csv`.
#
# Pour chaque exemple, il charge :
#
# - l’audio `.wav` avec `soundfile` ;
# - le spectrogramme Mel `.npy` avec `numpy`.
#
# Pour stabiliser l’entraînement, chaque exemple est ramené à une taille fixe :
#
# - un nombre fixe de frames Mel ;
# - une longueur audio correspondante.

# %%
class DiffWaveDODaDataset(Dataset):
    def __init__(self, dataframe, wav_dir, mel_dir, sample_rate=22050, hop_length=256, crop_mel_frames=62):
        self.df = dataframe.reset_index(drop=True)
        self.wav_dir = Path(wav_dir)
        self.mel_dir = Path(mel_dir)

        self.sample_rate = sample_rate
        self.hop_length = hop_length
        self.crop_mel_frames = crop_mel_frames
        self.audio_length = crop_mel_frames * hop_length

    def __len__(self):
        return len(self.df)

    def _resolve_wav_path(self, row):
        wav_path = Path(row["wav_path"])

        if wav_path.exists():
            return wav_path

        file_id = str(row["id"]).zfill(5)
        return self.wav_dir / f"{file_id}.wav"

    def _resolve_mel_path(self, row):
        mel_path = Path(row["mel_path"])

        if mel_path.exists():
            return mel_path

        file_id = str(row["id"]).zfill(5)
        return self.mel_dir / f"{file_id}.npy"

    def _pad_audio(self, audio):
        if len(audio) < self.audio_length:
            pad_len = self.audio_length - len(audio)
            audio = np.pad(audio, (0, pad_len), mode="constant")
        elif len(audio) > self.audio_length:
            audio = audio[:self.audio_length]

        return audio

    def _pad_mel(self, mel):
        if mel.shape[1] < self.crop_mel_frames:
            pad_len = self.crop_mel_frames - mel.shape[1]
            mel = np.pad(mel, ((0, 0), (0, pad_len)), mode="constant")
        elif mel.shape[1] > self.crop_mel_frames:
            mel = mel[:, :self.crop_mel_frames]

        return mel

    def __getitem__(self, idx):
        row = self.df.iloc[idx]

        wav_path = self._resolve_wav_path(row)
        mel_path = self._resolve_mel_path(row)

        audio, sr = sf.read(wav_path)

        if audio.ndim > 1:
            audio = np.mean(audio, axis=1)

        audio = audio.astype(np.float32)
        mel = np.load(mel_path).astype(np.float32)

        # Crop synchronisé entre le Mel et l'audio
        if mel.shape[1] > self.crop_mel_frames:
            max_start = mel.shape[1] - self.crop_mel_frames
            mel_start = np.random.randint(0, max_start + 1)
            mel_end = mel_start + self.crop_mel_frames

            audio_start = mel_start * self.hop_length
            audio_end = audio_start + self.audio_length

            mel = mel[:, mel_start:mel_end]
            audio = audio[audio_start:audio_end]

        audio = self._pad_audio(audio)
        mel = self._pad_mel(mel)

        audio = torch.tensor(audio, dtype=torch.float32)
        mel = torch.tensor(mel, dtype=torch.float32)

        return {
            "audio": audio,
            "mel": mel,
            "id": row["id"],
            "speaker": row["speaker"],
            "text_latin": row.get("text_latin", "")
        }

# %% [markdown]
# ## Création des DataLoaders
#
# Les DataLoaders permettent d’envoyer les données au modèle par batch.
#
# On crée ici :
#
# - un DataLoader pour l’entraînement ;
# - un DataLoader pour la validation.
#
# On commence avec un batch size modéré pour éviter de saturer la mémoire GPU.

# %%
BATCH_SIZE = 8

train_dataset = DiffWaveDODaDataset(
    dataframe=train_df,
    wav_dir=WAV_DIR,
    mel_dir=MEL_DIR,
    sample_rate=summary["sample_rate"],
    hop_length=summary["hop_length"],
    crop_mel_frames=params.crop_mel_frames
)

val_dataset = DiffWaveDODaDataset(
    dataframe=val_df,
    wav_dir=WAV_DIR,
    mel_dir=MEL_DIR,
    sample_rate=summary["sample_rate"],
    hop_length=summary["hop_length"],
    crop_mel_frames=params.crop_mel_frames
)

train_loader = DataLoader(
    train_dataset,
    batch_size=BATCH_SIZE,
    shuffle=True,
    num_workers=4,
    pin_memory=True,
    drop_last=True
)

val_loader = DataLoader(
    val_dataset,
    batch_size=BATCH_SIZE,
    shuffle=False,
    num_workers=4,
    pin_memory=True,
    drop_last=True
)

print("Nombre de batches train :", len(train_loader))
print("Nombre de batches validation :", len(val_loader))
# Out:
# Nombre de batches train : 811
# Nombre de batches validation : 90

# %% [markdown]
# ## Vérification d’un batch
#
# Avant de lancer l’entraînement, on vérifie qu’un batch se charge correctement.
#
# Cette étape est importante pour confirmer que :
#
# - les audios sont bien lus ;
# - les Mel spectrograms sont bien chargés ;
# - les dimensions sont compatibles avec DiffWave.

# %%
batch = next(iter(train_loader))

audio = batch["audio"]
mel = batch["mel"]

print("Audio shape :", audio.shape)
print("Mel shape :", mel.shape)
print("IDs :", batch["id"][:5])
print("Speakers :", batch["speaker"][:5])
# Out:
# Audio shape : torch.Size([8, 15872])
# Mel shape : torch.Size([8, 80, 62])
# IDs : tensor([ 1430, 10683,  6210,  6980, 11427])
# Speakers : ['M3', 'M1', 'M1', 'M1', 'M1']

# %% [markdown]
# ## Chargement du modèle DiffWave
#
# On instancie maintenant le modèle DiffWave avec les paramètres fournis par l’implémentation officielle.
#
# À ce stade, le modèle n’est pas encore entraîné sur notre dataset.
# Il est simplement créé avec ses poids initiaux.

# %%
model = DiffWave(params).to(device)

num_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
print("Nombre de paramètres entraînables :", num_params)
# Out:
# Nombre de paramètres entraînables : 2619971

# %%
PRETRAINED_PATH = PROJECT_DIR / "diffwave-ljspeech.pt"

model = DiffWave(params).to(device)
num_params = sum(p.numel() for p in model.parameters() if p.requires_grad)

if PRETRAINED_PATH.exists():
    ckpt = torch.load(PRETRAINED_PATH, map_location=device)
    # checkpoint officiel LJSpeech = directement les poids, pas de clé 'model_state_dict'
    if "model_state_dict" in ckpt:
        model.load_state_dict(ckpt["model_state_dict"], strict=False)
    else:
        model.load_state_dict(ckpt, strict=False)
    print("Fine-tuning : checkpoint LJSpeech chargé.")
else:
    print("From scratch : pas de checkpoint pré-entraîné.")
# Out:
# Fine-tuning : checkpoint LJSpeech chargé.

# %% [markdown]
# ## Test de passage dans le modèle
#
# Avant l’entraînement, on vérifie qu’un batch peut passer dans le modèle.
#
# On simule une étape de diffusion :
#
# 1. on prend un audio propre ;
# 2. on ajoute du bruit selon un pas de diffusion aléatoire ;
# 3. le modèle reçoit l’audio bruité, le pas de diffusion et le Mel ;
# 4. il prédit le bruit.
#
# Si cette cellule fonctionne sans erreur, on pourra passer à la boucle d’entraînement.

# %%
audio = batch["audio"].to(device)
mel = batch["mel"].to(device)

# Pas de diffusion aléatoire
t = torch.randint(
    low=0,
    high=len(params.noise_schedule),
    size=(audio.shape[0],),
    device=device
)

# Bruit ajouté
noise = torch.randn_like(audio)

# Schedule de bruit
noise_schedule = torch.tensor(params.noise_schedule, dtype=torch.float32, device=device)
alpha = 1.0 - noise_schedule
alpha_cum = torch.cumprod(alpha, dim=0)

sqrt_alpha_cum = torch.sqrt(alpha_cum[t]).unsqueeze(1)
sqrt_one_minus_alpha_cum = torch.sqrt(1.0 - alpha_cum[t]).unsqueeze(1)

# Création de l'audio bruité
noisy_audio = sqrt_alpha_cum * audio + sqrt_one_minus_alpha_cum * noise

# Passage dans le modèle
with torch.no_grad():
    predicted_noise = model(noisy_audio, t, mel)

print("Audio propre :", audio.shape)
print("Audio bruité :", noisy_audio.shape)
print("Bruit réel :", noise.shape)
print("Bruit prédit :", predicted_noise.shape)
# Out:
# Audio propre : torch.Size([8, 15872])
# Audio bruité : torch.Size([8, 15872])
# Bruit réel : torch.Size([8, 15872])
# Bruit prédit : torch.Size([8, 1, 15872])

# %% [markdown]
# # Fin de la préparation modèle
#
# À ce stade :
#
# - les données prétraitées sont chargées ;
# - le Dataset PyTorch fonctionne ;
# - les DataLoaders sont prêts ;
# - le modèle DiffWave est instancié ;
# - un premier forward pass a été testé.
#
# La prochaine étape sera l’entraînement du modèle et la sauvegarde d’un checkpoint.

# %% [markdown]
# # Entraînement de DiffWave sur DODa
#
# Dans cette partie, on entraîne le modèle DiffWave sur les données prétraitées.
#
# Le principe est le suivant :
#
# 1. On prend un audio propre.
# 2. On choisit un pas de diffusion aléatoire.
# 3. On ajoute du bruit à l’audio.
# 4. Le modèle reçoit l’audio bruité, le pas de diffusion et le spectrogramme Mel.
# 5. Le modèle doit prédire le bruit ajouté.
# 6. On optimise le modèle avec une MSE Loss.
#
# À la fin de l’entraînement, on sauvegarde un checkpoint qui sera utilisé pour la génération audio.

# %%
CHECKPOINT_DIR = PROJECT_DIR / "checkpoints"
FIGURES_DIR = PROJECT_DIR / "figures"
RESULTS_DIR = PROJECT_DIR / "results"

CHECKPOINT_DIR.mkdir(parents=True, exist_ok=True)
FIGURES_DIR.mkdir(parents=True, exist_ok=True)
RESULTS_DIR.mkdir(parents=True, exist_ok=True)

EXPERIMENT_NAME = "diffwave_doda_male"
EXPERIMENT_DIR = CHECKPOINT_DIR / EXPERIMENT_NAME
EXPERIMENT_DIR.mkdir(parents=True, exist_ok=True)

print("Dossier de l'expérience :", EXPERIMENT_DIR)
# Out:
# Dossier de l'expérience : /workspace/DiffWave_Project/checkpoints/diffwave_doda_male

# %%
# Préparation du noise schedule

noise_schedule = torch.tensor(
    params.noise_schedule,
    dtype=torch.float32,
    device=device
)

alphas = 1.0 - noise_schedule
alpha_cumprod = torch.cumprod(alphas, dim=0)

NUM_DIFFUSION_STEPS = len(params.noise_schedule)

print("Nombre de diffusion steps :", NUM_DIFFUSION_STEPS)
print("Noise schedule min :", noise_schedule.min().item())
print("Noise schedule max :", noise_schedule.max().item())


def add_noise_to_audio(clean_audio, diffusion_steps):
    """
    Ajoute du bruit à un audio propre selon un pas de diffusion.

    clean_audio : Tensor [B, T]
    diffusion_steps : Tensor [B]

    Retourne :
    - noisy_audio : audio bruité
    - noise : bruit réel ajouté
    """

    noise = torch.randn_like(clean_audio)

    sqrt_alpha_cumprod = torch.sqrt(alpha_cumprod[diffusion_steps]).unsqueeze(1)
    sqrt_one_minus_alpha_cumprod = torch.sqrt(
        1.0 - alpha_cumprod[diffusion_steps]
    ).unsqueeze(1)

    noisy_audio = (
        sqrt_alpha_cumprod * clean_audio
        + sqrt_one_minus_alpha_cumprod * noise
    )

    return noisy_audio, noise
# Out:
# Nombre de diffusion steps : 50
# Noise schedule min : 9.999999747378752e-05
# Noise schedule max : 0.05000000074505806

# %%
import torch.nn.functional as F

LEARNING_RATE = 2e-4

optimizer = torch.optim.Adam(
    model.parameters(),
    lr=LEARNING_RATE
)

scaler = torch.amp.GradScaler('cuda')

def stft_loss(x, y, fft_sizes=[512, 1024, 2048], hop_sizes=[128, 256, 512]):
    """Multi-resolution STFT loss pour capturer les détails fréquentiels."""
    loss = 0.0
    for fft_size, hop_size in zip(fft_sizes, hop_sizes):
        window = torch.hann_window(fft_size, device=x.device)
        X = torch.stft(x, fft_size, hop_size, return_complex=True, window=window)
        Y = torch.stft(y, fft_size, hop_size, return_complex=True, window=window)
        loss += F.l1_loss(X.abs().clamp(min=1e-8).log(), Y.abs().clamp(min=1e-8).log())
    return loss / len(fft_sizes)


STFT_WEIGHT = 0.1

print("Optimizer, scaler AMP et loss définis.")
print("Learning rate :", LEARNING_RATE)
# Out:
# Optimizer, scaler AMP et loss définis.
# Learning rate : 0.0002

# %% [markdown]
# ## Paramètres d'entraînement
#
# On commence avec un entraînement court pour vérifier que le pipeline fonctionne.
#
# L’objectif initial n’est pas d’obtenir une voix parfaite, mais de valider que :
#
# - les données passent correctement dans le modèle ;
# - la loss se calcule ;
# - le modèle apprend ;
# - un checkpoint peut être sauvegardé.
#
# Ensuite, on pourra augmenter le nombre de steps.

# %%
MAX_TRAIN_STEPS = 10000    # à augmenter si tout fonctionne
LOG_EVERY = 100
VALID_EVERY = 1000
SAVE_EVERY = 1000

GRAD_CLIP = 1.0

train_losses = []
val_losses = []

print("MAX_TRAIN_STEPS :", MAX_TRAIN_STEPS)
print("Validation toutes les", VALID_EVERY, "steps")
print("Sauvegarde toutes les", SAVE_EVERY, "steps")
# Out:
# MAX_TRAIN_STEPS : 10000
# Validation toutes les 1000 steps
# Sauvegarde toutes les 1000 steps

# %%
def validate_model(model, val_loader, max_batches=20):
    """
    Évalue rapidement le modèle sur quelques batches de validation.
    """

    model.eval()
    total_loss = 0.0
    n_batches = 0

    with torch.no_grad():
        for batch in val_loader:
            audio = batch["audio"].to(device)
            mel = batch["mel"].to(device)

            batch_size = audio.shape[0]

            diffusion_steps = torch.randint(
                low=0,
                high=NUM_DIFFUSION_STEPS,
                size=(batch_size,),
                device=device
            )

            noisy_audio, noise = add_noise_to_audio(audio, diffusion_steps)

            predicted_noise = model(noisy_audio, diffusion_steps, mel)
            if predicted_noise.dim() == 3:
                predicted_noise = predicted_noise.squeeze(1)

            mse = F.mse_loss(predicted_noise, noise)
            stft = stft_loss(predicted_noise, noise)
            loss = mse + STFT_WEIGHT * stft

            total_loss += loss.item()
            n_batches += 1

            if n_batches >= max_batches:
                break

    model.train()

    return total_loss / max(1, n_batches)

# %%
import time
from tqdm import tqdm

model.train()
global_step = 0
best_val_loss = float("inf")
train_start = time.time()

progress_bar = tqdm(total=MAX_TRAIN_STEPS, initial=global_step, desc="Entraînement", unit="step")

while global_step < MAX_TRAIN_STEPS:
    for batch in train_loader:
        audio = batch["audio"].to(device)
        mel = batch["mel"].to(device)
        batch_size = audio.shape[0]
        diffusion_steps = torch.randint(
            low=0,
            high=NUM_DIFFUSION_STEPS,
            size=(batch_size,),
            device=device
        )
        noisy_audio, noise = add_noise_to_audio(audio, diffusion_steps)
        with torch.amp.autocast('cuda'):
            predicted_noise = model(noisy_audio, diffusion_steps, mel)
            if predicted_noise.dim() == 3:
                predicted_noise = predicted_noise.squeeze(1)
                
            mse = F.mse_loss(predicted_noise, noise)
            stft = stft_loss(predicted_noise.float(), noise.float())
            loss = mse + STFT_WEIGHT * stft
        optimizer.zero_grad()
        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), GRAD_CLIP)
        optimizer.step()
        global_step += 1
        train_losses.append(loss.item())

        progress_bar.update(1)
        progress_bar.set_postfix({
            "loss": f"{loss.item():.6f}",
            "elapsed": f"{(time.time() - train_start)/60:.1f}min"
        })

        if global_step % LOG_EVERY == 0:
            elapsed = time.time() - train_start
            steps_remaining = MAX_TRAIN_STEPS - global_step
            eta = steps_remaining * (elapsed / global_step)
            tqdm.write(
                f"Step {global_step}/{MAX_TRAIN_STEPS} | "
                f"Train loss: {loss.item():.6f} | "
                f"Elapsed: {elapsed/60:.1f}min | "
                f"ETA: {eta/60:.1f}min"
            )

        if global_step % VALID_EVERY == 0:
            val_start = time.time()
            val_loss = validate_model(model, val_loader)
            val_duration = time.time() - val_start
            val_losses.append({
                "step": global_step,
                "val_loss": val_loss
            })
            tqdm.write(
                f"Step {global_step}/{MAX_TRAIN_STEPS} | "
                f"Val loss: {val_loss:.6f} | "
                f"Validation en {val_duration:.1f}s"
            )
            if val_loss < best_val_loss:
                best_val_loss = val_loss
                best_checkpoint_path = EXPERIMENT_DIR / "best_checkpoint.pt"
                torch.save({
                    "step": global_step,
                    "model_state_dict": model.state_dict(),
                    "optimizer_state_dict": optimizer.state_dict(),
                    "train_losses": train_losses,
                    "val_losses": val_losses,
                    "params": params.__dict__ if hasattr(params, "__dict__") else None,
                    "summary": summary
                }, best_checkpoint_path)
                tqdm.write("Meilleur checkpoint sauvegardé : " + str(best_checkpoint_path))

        if global_step % SAVE_EVERY == 0:
            last_checkpoint_path = EXPERIMENT_DIR / "last_checkpoint.pt"
            torch.save({
                "step": global_step,
                "model_state_dict": model.state_dict(),
                "optimizer_state_dict": optimizer.state_dict(),
                "train_losses": train_losses,
                "val_losses": val_losses,
                "params": params.__dict__ if hasattr(params, "__dict__") else None,
                "summary": summary
            }, last_checkpoint_path)
            tqdm.write("Dernier checkpoint sauvegardé : " + str(last_checkpoint_path))

        if global_step >= MAX_TRAIN_STEPS:
            break

progress_bar.close()
total_time = time.time() - train_start
print(f"Entraînement terminé en {total_time/60:.1f}min ({total_time/3600:.2f}h).")
# Out:
# Entraînement:   0%|          | 0/10000 [00:00<?, ?step/s]
# Entraînement:   0%|          | 34/10000 [00:45<3:43:11,  1.34s/step, loss=1.330127, elapsed=0.2min]
# Entraînement:   0%|          | 1/10000 [00:00<1:09:53,  2.38step/s]
# Entraînement:   0%|          | 1/10000 [00:00<1:09:53,  2.38step/s, loss=2.880355, elapsed=0.0min]
# Entraînement:   0%|          | 2/10000 [00:00<47:52,  3.48step/s, loss=2.880355, elapsed=0.0min]
# Entraînement:   0%|          | 2/10000 [00:00<47:52,  3.48step/s, loss=1.829675, elapsed=0.0min]
# Entraînement:   0%|          | 3/10000 [00:00<40:28,  4.12step/s, loss=1.829675, elapsed=0.0min]
# Entraînement:   0%|          | 3/10000 [00:00<40:28,  4.12step/s, loss=1.781127, elapsed=0.0min]
# Entraînement:   0%|          | 4/10000 [00:00<36:56,  4.51step/s, loss=1.781127, elapsed=0.0min]
# Entraînement:   0%|          | 4/10000 [00:00<36:56,  4.51step/s, loss=1.689373, elapsed=0.0min]
# Entraînement:   0%|          | 5/10000 [00:01<35:00,  4.76step/s, loss=1.689373, elapsed=0.0min]
# Entraînement:   0%|          | 5/10000 [00:01<35:00,  4.76step/s, loss=1.667945, elapsed=0.0min]
# Entraînement:   0%|          | 6/10000 [00:01<33:48,  4.93step/s, loss=1.667945, elapsed=0.0min]
# Entraînement:   0%|          | 6/10000 [00:01<33:48,  4.93step/s, loss=1.647276, elapsed=0.0min]
# Entraînement:   0%|          | 7/10000 [00:01<33:06,  5.03step/s, loss=1.647276, elapsed=0.0min]
# Entraînement:   0%|          | 7/10000 [00:01<33:06,  5.03step/s, loss=1.585409, elapsed=0.0min]
# Entraînement:   0%|          | 8/10000 [00:01<32:39,  5.10step/s, loss=1.585409, elapsed=0.0min]
# Entraînement:   0%|          | 8/10000 [00:01<32:39,  5.10step/s, loss=1.552618, elapsed=0.0min]
# Entraînement:   0%|          | 9/10000 [00:01<32:17,  5.16step/s, loss=1.552618, elapsed=0.0min]
# Entraînement:   0%|          | 9/10000 [00:01<32:17,  5.16step/s, loss=1.544047, elapsed=0.0min]
# Entraînement:   0%|          | 10/10000 [00:02<32:05,  5.19step/s, loss=1.544047, elapsed=0.0min]
# Entraînement:   0%|          | 10/10000 [00:02<32:05,  5.19step/s, loss=1.543812, elapsed=0.0min]
# Entraînement:   0%|          | 11/10000 [00:02<31:52,  5.22step/s, loss=1.543812, elapsed=0.0min]
# Entraînement:   0%|          | 11/10000 [00:02<31:52,  5.22step/s, loss=1.544677, elapsed=0.0min]
# Entraînement:   0%|          | 12/10000 [00:02<31:49,  5.23step/s, loss=1.544677, elapsed=0.0min]
# Entraînement:   0%|          | 12/10000 [00:02<31:49,  5.23step/s, loss=1.464852, elapsed=0.0min]
# Entraînement:   0%|          | 13/10000 [00:02<31:43,  5.25step/s, loss=1.464852, elapsed=0.0min]
# Entraînement:   0%|          | 13/10000 [00:02<31:43,  5.25step/s, loss=1.455277, elapsed=0.0min]
# Entraînement:   0%|          | 14/10000 [00:02<31:37,  5.26step/s, loss=1.455277, elapsed=0.0min]
# Entraînement:   0%|          | 14/10000 [00:02<31:37,  5.26step/s, loss=1.454767, elapsed=0.0min]
# Entraînement:   0%|          | 15/10000 [00:03<31:36,  5.27step/s, loss=1.454767, elapsed=0.0min]
# Entraînement:   0%|          | 15/10000 [00:03<31:36,  5.27step/s, loss=1.435920, elapsed=0.1min]
# Entraînement:   0%|          | 16/10000 [00:03<31:33,  5.27step/s, loss=1.435920, elapsed=0.1min]
# Entraînement:   0%|          | 16/10000 [00:03<31:33,  5.27step/s, loss=1.424067, elapsed=0.1min]
# Entraînement:   0%|          | 17/10000 [00:03<31:36,  5.26step/s, loss=1.424067, elapsed=0.1min]
# Entraînement:   0%|          | 17/10000 [00:03<31:36,  5.26step/s, loss=1.397201, elapsed=0.1min]
# Entraînement:   0%|          | 18/10000 [00:03<31:35,  5.27step/s, loss=1.397201, elapsed=0.1min]
# Entraînement:   0%|          | 18/10000 [00:03<31:35,  5.27step/s, loss=1.391031, elapsed=0.1min]
# Entraînement:   0%|          | 19/10000 [00:03<31:34,  5.27step/s, loss=1.391031, elapsed=0.1min]
# Entraînement:   0%|          | 19/10000 [00:03<31:34,  5.27step/s, loss=1.361299, elapsed=0.1min]
# Entraînement:   0%|          | 20/10000 [00:04<31:35,  5.27step/s, loss=1.361299, elapsed=0.1min]
# Entraînement:   0%|          | 20/10000 [00:04<31:35,  5.27step/s, loss=1.354428, elapsed=0.1min]
# Entraînement:   0%|          | 21/10000 [00:04<31:43,  5.24step/s, loss=1.354428, elapsed=0.1min]
# Entraînement:   0%|          | 21/10000 [00:04<31:43,  5.24step/s, loss=1.313038, elapsed=0.1min]
# Entraînement:   0%|          | 22/10000 [00:04<31:46,  5.23step/s, loss=1.313038, elapsed=0.1min]
# Entraînement:   0%|          | 22/10000 [00:04<31:46,  5.23step/s, loss=1.309621, elapsed=0.1min]
# Entraînement:   0%|          | 23/10000 [00:04<31:53,  5.21step/s, loss=1.309621, elapsed=0.1min]
# Entraînement:   0%|          | 23/10000 [00:04<31:53,  5.21step/s, loss=1.304945, elapsed=0.1min]
# Entraînement:   0%|          | 24/10000 [00:04<31:53,  5.21step/s, loss=1.304945, elapsed=0.1min]
# Entraînement:   0%|          | 24/10000 [00:04<31:53,  5.21step/s, loss=1.292094, elapsed=0.1min]
# Entraînement:   0%|          | 25/10000 [00:04<31:48,  5.23step/s, loss=1.292094, elapsed=0.1min]
# Entraînement:   0%|          | 25/10000 [00:04<31:48,  5.23step/s, loss=1.259210, elapsed=0.1min]
# Entraînement:   0%|          | 26/10000 [00:05<31:31,  5.27step/s, loss=1.259210, elapsed=0.1min]
# Entraînement:   0%|          | 26/10000 [00:05<31:31,  5.27step/s, loss=1.244481, elapsed=0.1min]
# Entraînement:   0%|          | 27/10000 [00:05<31:30,  5.28step/s, loss=1.244481, elapsed=0.1min]
# Entraînement:   0%|          | 27/10000 [00:05<31:30,  5.28step/s, loss=1.230320, elapsed=0.1min]
# Entraînement:   0%|          | 28/10000 [00:05<31:30,  5.27step/s, loss=1.230320, elapsed=0.1min]
# Entraînement:   0%|          | 28/10000 [00:05<31:30,  5.27step/s, loss=1.202809, elapsed=0.1min]
# Entraînement:   0%|          | 29/10000 [00:05<31:28,  5.28step/s, loss=1.202809, elapsed=0.1min]
# Entraînement:   0%|          | 29/10000 [00:05<31:28,  5.28step/s, loss=1.190603, elapsed=0.1min]
# Entraînement:   0%|          | 30/10000 [00:05<31:29,  5.28step/s, loss=1.190603, elapsed=0.1min]
# Entraînement:   0%|          | 30/10000 [00:05<31:29,  5.28step/s, loss=1.119529, elapsed=0.1min]
# Entraînement:   0%|          | 31/10000 [00:06<31:33,  5.26step/s, loss=1.119529, elapsed=0.1min]
# Entraînement:   0%|          | 31/10000 [00:06<31:33,  5.26step/s, loss=1.110092, elapsed=0.1min]
# Entraînement:   0%|          | 32/10000 [00:06<31:34,  5.26step/s, loss=1.110092, elapsed=0.1min]
# Entraînement:   0%|          | 32/10000 [00:06<31:34,  5.26step/s, loss=1.082565, elapsed=0.1min]
# Entraînement:   0%|          | 33/10000 [00:06<31:35,  5.26step/s, loss=1.082565, elapsed=0.1min]
# Entraînement:   0%|          | 33/10000 [00:06<31:35,  5.26step/s, loss=1.052408, elapsed=0.1min]
# Entraînement:   0%|          | 34/10000 [00:06<31:33,  5.26step/s, loss=1.052408, elapsed=0.1min]
# Entraînement:   0%|          | 34/10000 [00:06<31:33,  5.26step/s, loss=1.011536, elapsed=0.1min]
# Entraînement:   0%|          | 35/10000 [00:06<31:34,  5.26step/s, loss=1.011536, elapsed=0.1min]
# Entraînement:   0%|          | 35/10000 [00:06<31:34,  5.26step/s, loss=0.954068, elapsed=0.1min]
# Entraînement:   0%|          | 36/10000 [00:07<31:32,  5.27step/s, loss=0.954068, elapsed=0.1min]
# Entraînement:   0%|          | 36/10000 [00:07<31:32,  5.27step/s, loss=0.946201, elapsed=0.1min]
# Entraînement:   0%|          | 37/10000 [00:07<31:30,  5.27step/s, loss=0.946201, elapsed=0.1min]
# Entraînement:   0%|          | 37/10000 [00:07<31:30,  5.27step/s, loss=0.853984, elapsed=0.1min]
# Entraînement:   0%|          | 38/10000 [00:07<31:31,  5.27step/s, loss=0.853984, elapsed=0.1min]
# Entraînement:   0%|          | 38/10000 [00:07<31:31,  5.27step/s, loss=0.777199, elapsed=0.1min]
# Entraînement:   0%|          | 39/10000 [00:07<31:28,  5.28step/s, loss=0.777199, elapsed=0.1min]
# Entraînement:   0%|          | 39/10000 [00:07<31:28,  5.28step/s, loss=0.722812, elapsed=0.1min]
# Entraînement:   0%|          | 40/10000 [00:07<31:30,  5.27step/s, loss=0.722812, elapsed=0.1min]
# Entraînement:   0%|          | 40/10000 [00:07<31:30,  5.27step/s, loss=0.661686, elapsed=0.1min]
# Entraînement:   0%|          | 41/10000 [00:08<31:29,  5.27step/s, loss=0.661686, elapsed=0.1min]
# Entraînement:   0%|          | 41/10000 [00:08<31:29,  5.27step/s, loss=0.605384, elapsed=0.1min]
# Entraînement:   0%|          | 42/10000 [00:08<31:28,  5.27step/s, loss=0.605384, elapsed=0.1min]
# Entraînement:   0%|          | 42/10000 [00:08<31:28,  5.27step/s, loss=0.656247, elapsed=0.1min]
# Entraînement:   0%|          | 43/10000 [00:08<31:30,  5.27step/s, loss=0.656247, elapsed=0.1min]
# Entraînement:   0%|          | 43/10000 [00:08<31:30,  5.27step/s, loss=0.558427, elapsed=0.1min]
# Entraînement:   0%|          | 44/10000 [00:08<31:27,  5.28step/s, loss=0.558427, elapsed=0.1min]
# Entraînement:   0%|          | 44/10000 [00:08<31:27,  5.28step/s, loss=0.447190, elapsed=0.1min]
# Entraînement:   0%|          | 45/10000 [00:08<31:28,  5.27step/s, loss=0.447190, elapsed=0.1min]
# Entraînement:   0%|          | 45/10000 [00:08<31:28,  5.27step/s, loss=0.397848, elapsed=0.1min]
# Entraînement:   0%|          | 46/10000 [00:08<31:25,  5.28step/s, loss=0.397848, elapsed=0.1min]
# Entraînement:   0%|          | 46/10000 [00:08<31:25,  5.28step/s, loss=0.343730, elapsed=0.1min]
# Entraînement:   0%|          | 47/10000 [00:09<31:29,  5.27step/s, loss=0.343730, elapsed=0.1min]
# Entraînement:   0%|          | 47/10000 [00:09<31:29,  5.27step/s, loss=0.328934, elapsed=0.2min]
# Entraînement:   0%|          | 48/10000 [00:09<31:25,  5.28step/s, loss=0.328934, elapsed=0.2min]
# Entraînement:   0%|          | 48/10000 [00:09<31:25,  5.28step/s, loss=0.315253, elapsed=0.2min]
# Entraînement:   0%|          | 49/10000 [00:09<31:32,  5.26step/s, loss=0.315253, elapsed=0.2min]
# Entraînement:   0%|          | 49/10000 [00:09<31:32,  5.26step/s, loss=0.277173, elapsed=0.2min]
# Entraînement:   0%|          | 50/10000 [00:09<31:37,  5.24step/s, loss=0.277173, elapsed=0.2min]
# Entraînement:   0%|          | 50/10000 [00:09<31:37,  5.24step/s, loss=0.343157, elapsed=0.2min]
# Entraînement:   1%|          | 51/10000 [00:09<31:38,  5.24step/s, loss=0.343157, elapsed=0.2min]
# Entraînement:   1%|          | 51/10000 [00:09<31:38,  5.24step/s, loss=0.440498, elapsed=0.2min]
# Entraînement:   1%|          | 52/10000 [00:10<31:33,  5.25step/s, loss=0.440498, elapsed=0.2min]
# Entraînement:   1%|          | 52/10000 [00:10<31:33,  5.25step/s, loss=0.245882, elapsed=0.2min]
# Entraînement:   1%|          | 53/10000 [00:10<31:32,  5.26step/s, loss=0.245882, elapsed=0.2min]
# Entraînement:   1%|          | 53/10000 [00:10<31:32,  5.26step/s, loss=0.357970, elapsed=0.2min]
# Entraînement:   1%|          | 54/10000 [00:10<31:35,  5.25step/s, loss=0.357970, elapsed=0.2min]
# Entraînement:   1%|          | 54/10000 [00:10<31:35,  5.25step/s, loss=0.242296, elapsed=0.2min]
# Entraînement:   1%|          | 55/10000 [00:10<31:34,  5.25step/s, loss=0.242296, elapsed=0.2min]
# Entraînement:   1%|          | 55/10000 [00:10<31:34,  5.25step/s, loss=0.228223, elapsed=0.2min]
# Entraînement:   1%|          | 56/10000 [00:10<31:32,  5.26step/s, loss=0.228223, elapsed=0.2min]
# Entraînement:   1%|          | 56/10000 [00:10<31:32,  5.26step/s, loss=0.346099, elapsed=0.2min]
# Entraînement:   1%|          | 57/10000 [00:11<31:27,  5.27step/s, loss=0.346099, elapsed=0.2min]
# Entraînement:   1%|          | 57/10000 [00:11<31:27,  5.27step/s, loss=0.205690, elapsed=0.2min]
# Entraînement:   1%|          | 58/10000 [00:11<31:25,  5.27step/s, loss=0.205690, elapsed=0.2min]
# Entraînement:   1%|          | 58/10000 [00:11<31:25,  5.27step/s, loss=0.243174, elapsed=0.2min]
# Entraînement:   1%|          | 59/10000 [00:11<31:24,  5.27step/s, loss=0.243174, elapsed=0.2min]
# Entraînement:   1%|          | 59/10000 [00:11<31:24,  5.27step/s, loss=0.268138, elapsed=0.2min]
# Entraînement:   1%|          | 60/10000 [00:11<31:26,  5.27step/s, loss=0.268138, elapsed=0.2min]
# Entraînement:   1%|          | 60/10000 [00:11<31:26,  5.27step/s, loss=0.272893, elapsed=0.2min]
# Entraînement:   1%|          | 61/10000 [00:11<31:28,  5.26step/s, loss=0.272893, elapsed=0.2min]
# Entraînement:   1%|          | 61/10000 [00:11<31:28,  5.26step/s, loss=0.196201, elapsed=0.2min]
# Entraînement:   1%|          | 62/10000 [00:12<31:28,  5.26step/s, loss=0.196201, elapsed=0.2min]
# Entraînement:   1%|          | 62/10000 [00:12<31:28,  5.26step/s, loss=0.541533, elapsed=0.2min]
# Entraînement:   1%|          | 63/10000 [00:12<31:32,  5.25step/s, loss=0.541533, elapsed=0.2min]
# Entraînement:   1%|          | 63/10000 [00:12<31:32,  5.25step/s, loss=0.191615, elapsed=0.2min]
# Entraînement:   1%|          | 64/10000 [00:12<31:28,  5.26step/s, loss=0.191615, elapsed=0.2min]
# Entraînement:   1%|          | 64/10000 [00:12<31:28,  5.26step/s, loss=0.188642, elapsed=0.2min]
# Entraînement:   1%|          | 65/10000 [00:12<31:28,  5.26step/s, loss=0.188642, elapsed=0.2min]
# Entraînement:   1%|          | 65/10000 [00:12<31:28,  5.26step/s, loss=0.437202, elapsed=0.2min]
# Entraînement:   1%|          | 66/10000 [00:12<31:25,  5.27step/s, loss=0.437202, elapsed=0.2min]
# Entraînement:   1%|          | 66/10000 [00:12<31:25,  5.27step/s, loss=0.198214, elapsed=0.2min]
# Entraînement:   1%|          | 67/10000 [00:12<31:25,  5.27step/s, loss=0.198214, elapsed=0.2min]
# Entraînement:   1%|          | 67/10000 [00:12<31:25,  5.27step/s, loss=0.247492, elapsed=0.2min]
# Entraînement:   1%|          | 68/10000 [00:13<31:26,  5.27step/s, loss=0.247492, elapsed=0.2min]
# Entraînement:   1%|          | 68/10000 [00:13<31:26,  5.27step/s, loss=0.378197, elapsed=0.2min]
# Entraînement:   1%|          | 69/10000 [00:13<31:30,  5.25step/s, loss=0.378197, elapsed=0.2min]
# Entraînement:   1%|          | 69/10000 [00:13<31:30,  5.25step/s, loss=0.189121, elapsed=0.2min]
# Entraînement:   1%|          | 70/10000 [00:13<31:34,  5.24step/s, loss=0.189121, elapsed=0.2min]
# Entraînement:   1%|          | 70/10000 [00:13<31:34,  5.24step/s, loss=0.165012, elapsed=0.2min]
# Entraînement:   1%|          | 71/10000 [00:13<31:37,  5.23step/s, loss=0.165012, elapsed=0.2min]
# Entraînement:   1%|          | 71/10000 [00:13<31:37,  5.23step/s, loss=0.148906, elapsed=0.2min]
# Entraînement:   1%|          | 72/10000 [00:13<31:40,  5.22step/s, loss=0.148906, elapsed=0.2min]
# Entraînement:   1%|          | 72/10000 [00:13<31:40,  5.22step/s, loss=0.249586, elapsed=0.2min]
# Entraînement:   1%|          | 73/10000 [00:14<31:41,  5.22step/s, loss=0.249586, elapsed=0.2min]
# Entraînement:   1%|          | 73/10000 [00:14<31:41,  5.22step/s, loss=0.398670, elapsed=0.2min]
# Entraînement:   1%|          | 74/10000 [00:14<31:53,  5.19step/s, loss=0.398670, elapsed=0.2min]
# Entraînement:   1%|          | 74/10000 [00:14<31:53,  5.19step/s, loss=0.396140, elapsed=0.2min]
# Entraînement:   1%|          | 75/10000 [00:14<31:47,  5.20step/s, loss=0.396140, elapsed=0.2min]
# Entraînement:   1%|          | 75/10000 [00:14<31:47,  5.20step/s, loss=0.240465, elapsed=0.2min]
# Entraînement:   1%|          | 76/10000 [00:14<31:40,  5.22step/s, loss=0.240465, elapsed=0.2min]
# Entraînement:   1%|          | 76/10000 [00:14<31:40,  5.22step/s, loss=0.319040, elapsed=0.2min]
# Entraînement:   1%|          | 77/10000 [00:14<31:50,  5.19step/s, loss=0.319040, elapsed=0.2min]
# Entraînement:   1%|          | 77/10000 [00:14<31:50,  5.19step/s, loss=0.176723, elapsed=0.2min]
# Entraînement:   1%|          | 78/10000 [00:15<31:41,  5.22step/s, loss=0.176723, elapsed=0.2min]
# Entraînement:   1%|          | 78/10000 [00:15<31:41,  5.22step/s, loss=0.259199, elapsed=0.3min]
# Entraînement:   1%|          | 79/10000 [00:15<31:40,  5.22step/s, loss=0.259199, elapsed=0.3min]
# Entraînement:   1%|          | 79/10000 [00:15<31:40,  5.22step/s, loss=0.285155, elapsed=0.3min]
# Entraînement:   1%|          | 80/10000 [00:15<31:36,  5.23step/s, loss=0.285155, elapsed=0.3min]
# Entraînement:   1%|          | 80/10000 [00:15<31:36,  5.23step/s, loss=0.162813, elapsed=0.3min]
# Entraînement:   1%|          | 81/10000 [00:15<31:38,  5.22step/s, loss=0.162813, elapsed=0.3min]
# Entraînement:   1%|          | 81/10000 [00:15<31:38,  5.22step/s, loss=0.159532, elapsed=0.3min]
# Entraînement:   1%|          | 82/10000 [00:15<31:33,  5.24step/s, loss=0.159532, elapsed=0.3min]
# Entraînement:   1%|          | 82/10000 [00:15<31:33,  5.24step/s, loss=0.201462, elapsed=0.3min]
# Entraînement:   1%|          | 83/10000 [00:16<31:32,  5.24step/s, loss=0.201462, elapsed=0.3min]
# Entraînement:   1%|          | 83/10000 [00:16<31:32,  5.24step/s, loss=0.261821, elapsed=0.3min]
# Entraînement:   1%|          | 84/10000 [00:16<31:33,  5.24step/s, loss=0.261821, elapsed=0.3min]
# Entraînement:   1%|          | 84/10000 [00:16<31:33,  5.24step/s, loss=0.116660, elapsed=0.3min]
# Entraînement:   1%|          | 85/10000 [00:16<31:32,  5.24step/s, loss=0.116660, elapsed=0.3min]
# Entraînement:   1%|          | 85/10000 [00:16<31:32,  5.24step/s, loss=0.150812, elapsed=0.3min]
# Entraînement:   1%|          | 86/10000 [00:16<31:31,  5.24step/s, loss=0.150812, elapsed=0.3min]
# Entraînement:   1%|          | 86/10000 [00:16<31:31,  5.24step/s, loss=0.139014, elapsed=0.3min]
# Entraînement:   1%|          | 87/10000 [00:16<31:31,  5.24step/s, loss=0.139014, elapsed=0.3min]
# Entraînement:   1%|          | 87/10000 [00:16<31:31,  5.24step/s, loss=0.110026, elapsed=0.3min]
# Entraînement:   1%|          | 88/10000 [00:16<31:29,  5.25step/s, loss=0.110026, elapsed=0.3min]
# Entraînement:   1%|          | 88/10000 [00:16<31:29,  5.25step/s, loss=0.140605, elapsed=0.3min]
# Entraînement:   1%|          | 89/10000 [00:17<31:28,  5.25step/s, loss=0.140605, elapsed=0.3min]
# Entraînement:   1%|          | 89/10000 [00:17<31:28,  5.25step/s, loss=0.166642, elapsed=0.3min]
# Entraînement:   1%|          | 90/10000 [00:17<31:25,  5.26step/s, loss=0.166642, elapsed=0.3min]
# Entraînement:   1%|          | 90/10000 [00:17<31:25,  5.26step/s, loss=0.111693, elapsed=0.3min]
# Entraînement:   1%|          | 91/10000 [00:17<31:30,  5.24step/s, loss=0.111693, elapsed=0.3min]
# Entraînement:   1%|          | 91/10000 [00:17<31:30,  5.24step/s, loss=0.161981, elapsed=0.3min]
# Entraînement:   1%|          | 92/10000 [00:17<31:33,  5.23step/s, loss=0.161981, elapsed=0.3min]
# Entraînement:   1%|          | 92/10000 [00:17<31:33,  5.23step/s, loss=0.100927, elapsed=0.3min]
# Entraînement:   1%|          | 93/10000 [00:17<31:37,  5.22step/s, loss=0.100927, elapsed=0.3min]
# Entraînement:   1%|          | 93/10000 [00:17<31:37,  5.22step/s, loss=0.146533, elapsed=0.3min]
# Entraînement:   1%|          | 94/10000 [00:18<31:30,  5.24step/s, loss=0.146533, elapsed=0.3min]
# Entraînement:   1%|          | 94/10000 [00:18<31:30,  5.24step/s, loss=0.141953, elapsed=0.3min]
# Entraînement:   1%|          | 95/10000 [00:18<31:33,  5.23step/s, loss=0.141953, elapsed=0.3min]
# Entraînement:   1%|          | 95/10000 [00:18<31:33,  5.23step/s, loss=0.218468, elapsed=0.3min]
# Entraînement:   1%|          | 96/10000 [00:18<31:29,  5.24step/s, loss=0.218468, elapsed=0.3min]
# Entraînement:   1%|          | 96/10000 [00:18<31:29,  5.24step/s, loss=0.210093, elapsed=0.3min]
# Entraînement:   1%|          | 97/10000 [00:18<31:33,  5.23step/s, loss=0.210093, elapsed=0.3min]
# Entraînement:   1%|          | 97/10000 [00:18<31:33,  5.23step/s, loss=0.120966, elapsed=0.3min]
# Entraînement:   1%|          | 98/10000 [00:18<31:28,  5.24step/s, loss=0.120966, elapsed=0.3min]
# Entraînement:   1%|          | 98/10000 [00:18<31:28,  5.24step/s, loss=0.129322, elapsed=0.3min]
# Entraînement:   1%|          | 99/10000 [00:19<31:33,  5.23step/s, loss=0.129322, elapsed=0.3min]
# Entraînement:   1%|          | 99/10000 [00:19<31:33,  5.23step/s, loss=0.146360, elapsed=0.3min]
# Entraînement:   1%|          | 100/10000 [00:19<31:31,  5.24step/s, loss=0.146360, elapsed=0.3min]
# Entraînement:   1%|          | 100/10000 [00:19<31:31,  5.24step/s, loss=0.109116, elapsed=0.3min]
# Entraînement:   1%|          | 100/10000 [00:19<31:31,  5.24step/s, loss=0.109116, elapsed=0.3min]
# Entraînement:   1%|          | 101/10000 [00:19<31:49,  5.18step/s, loss=0.109116, elapsed=0.3min]
# Entraînement:   1%|          | 101/10000 [00:19<31:49,  5.18step/s, loss=0.083736, elapsed=0.3min]
# Step 100/10000 | Train loss: 0.109116 | Elapsed: 0.3min | ETA: 31.8min
# Entraînement:   1%|          | 102/10000 [00:19<31:39,  5.21step/s, loss=0.083736, elapsed=0.3min]
# Entraînement:   1%|          | 102/10000 [00:19<31:39,  5.21step/s, loss=0.249410, elapsed=0.3min]
# Entraînement:   1%|          | 103/10000 [00:19<31:34,  5.22step/s, loss=0.249410, elapsed=0.3min]
# Entraînement:   1%|          | 103/10000 [00:19<31:34,  5.22step/s, loss=0.147559, elapsed=0.3min]
# Entraînement:   1%|          | 104/10000 [00:20<31:29,  5.24step/s, loss=0.147559, elapsed=0.3min]
# Entraînement:   1%|          | 104/10000 [00:20<31:29,  5.24step/s, loss=0.110912, elapsed=0.3min]
# Entraînement:   1%|          | 105/10000 [00:20<31:23,  5.25step/s, loss=0.110912, elapsed=0.3min]
# Entraînement:   1%|          | 105/10000 [00:20<31:23,  5.25step/s, loss=0.122400, elapsed=0.3min]
# Entraînement:   1%|          | 106/10000 [00:20<31:22,  5.26step/s, loss=0.122400, elapsed=0.3min]
# Entraînement:   1%|          | 106/10000 [00:20<31:22,  5.26step/s, loss=0.152566, elapsed=0.3min]
# Entraînement:   1%|          | 107/10000 [00:20<31:24,  5.25step/s, loss=0.152566, elapsed=0.3min]
# Entraînement:   1%|          | 107/10000 [00:20<31:24,  5.25step/s, loss=0.092347, elapsed=0.3min]
# Entraînement:   1%|          | 108/10000 [00:20<31:26,  5.24step/s, loss=0.092347, elapsed=0.3min]
# Entraînement:   1%|          | 108/10000 [00:20<31:26,  5.24step/s, loss=0.103735, elapsed=0.3min]
# Entraînement:   1%|          | 109/10000 [00:20<31:21,  5.26step/s, loss=0.103735, elapsed=0.3min]
# Entraînement:   1%|          | 109/10000 [00:20<31:21,  5.26step/s, loss=0.226307, elapsed=0.3min]
# Entraînement:   1%|          | 110/10000 [00:21<31:19,  5.26step/s, loss=0.226307, elapsed=0.3min]
# Entraînement:   1%|          | 110/10000 [00:21<31:19,  5.26step/s, loss=0.248703, elapsed=0.4min]
# Entraînement:   1%|          | 111/10000 [00:21<31:17,  5.27step/s, loss=0.248703, elapsed=0.4min]
# Entraînement:   1%|          | 111/10000 [00:21<31:17,  5.27step/s, loss=0.117133, elapsed=0.4min]
# Entraînement:   1%|          | 112/10000 [00:21<31:15,  5.27step/s, loss=0.117133, elapsed=0.4min]
# Entraînement:   1%|          | 112/10000 [00:21<31:15,  5.27step/s, loss=0.114062, elapsed=0.4min]
# Entraînement:   1%|          | 113/10000 [00:21<31:16,  5.27step/s, loss=0.114062, elapsed=0.4min]
# Entraînement:   1%|          | 113/10000 [00:21<31:16,  5.27step/s, loss=0.158683, elapsed=0.4min]
# Entraînement:   1%|          | 114/10000 [00:21<31:15,  5.27step/s, loss=0.158683, elapsed=0.4min]
# Entraînement:   1%|          | 114/10000 [00:21<31:15,  5.27step/s, loss=0.086746, elapsed=0.4min]
# Entraînement:   1%|          | 115/10000 [00:22<31:16,  5.27step/s, loss=0.086746, elapsed=0.4min]
# Entraînement:   1%|          | 115/10000 [00:22<31:16,  5.27step/s, loss=0.090636, elapsed=0.4min]
# Entraînement:   1%|          | 116/10000 [00:22<31:14,  5.27step/s, loss=0.090636, elapsed=0.4min]
# Entraînement:   1%|          | 116/10000 [00:22<31:14,  5.27step/s, loss=0.125262, elapsed=0.4min]
# Entraînement:   1%|          | 117/10000 [00:22<31:15,  5.27step/s, loss=0.125262, elapsed=0.4min]
# Entraînement:   1%|          | 117/10000 [00:22<31:15,  5.27step/s, loss=0.090863, elapsed=0.4min]
# Entraînement:   1%|          | 118/10000 [00:22<31:14,  5.27step/s, loss=0.090863, elapsed=0.4min]
# Entraînement:   1%|          | 118/10000 [00:22<31:14,  5.27step/s, loss=0.076679, elapsed=0.4min]
# Entraînement:   1%|          | 119/10000 [00:22<31:15,  5.27step/s, loss=0.076679, elapsed=0.4min]
# Entraînement:   1%|          | 119/10000 [00:22<31:15,  5.27step/s, loss=0.075451, elapsed=0.4min]
# Entraînement:   1%|          | 120/10000 [00:23<31:13,  5.27step/s, loss=0.075451, elapsed=0.4min]
# Entraînement:   1%|          | 120/10000 [00:23<31:13,  5.27step/s, loss=0.158243, elapsed=0.4min]
# Entraînement:   1%|          | 121/10000 [00:23<31:12,  5.28step/s, loss=0.158243, elapsed=0.4min]
# Entraînement:   1%|          | 121/10000 [00:23<31:12,  5.28step/s, loss=0.081247, elapsed=0.4min]
# Entraînement:   1%|          | 122/10000 [00:23<31:18,  5.26step/s, loss=0.081247, elapsed=0.4min]
# Entraînement:   1%|          | 122/10000 [00:23<31:18,  5.26step/s, loss=0.136998, elapsed=0.4min]
# Entraînement:   1%|          | 123/10000 [00:23<31:19,  5.26step/s, loss=0.136998, elapsed=0.4min]
# Entraînement:   1%|          | 123/10000 [00:23<31:19,  5.26step/s, loss=0.099544, elapsed=0.4min]
# Entraînement:   1%|          | 124/10000 [00:23<31:26,  5.23step/s, loss=0.099544, elapsed=0.4min]
# Entraînement:   1%|          | 124/10000 [00:23<31:26,  5.23step/s, loss=0.084973, elapsed=0.4min]
# Entraînement:   1%|▏         | 125/10000 [00:24<31:22,  5.24step/s, loss=0.084973, elapsed=0.4min]
# Entraînement:   1%|▏         | 125/10000 [00:24<31:22,  5.24step/s, loss=0.086716, elapsed=0.4min]
# Entraînement:   1%|▏         | 126/10000 [00:24<31:18,  5.26step/s, loss=0.086716, elapsed=0.4min]
# Entraînement:   1%|▏         | 126/10000 [00:24<31:18,  5.26step/s, loss=0.072945, elapsed=0.4min]
# Entraînement:   1%|▏         | 127/10000 [00:24<31:14,  5.27step/s, loss=0.072945, elapsed=0.4min]
# Entraînement:   1%|▏         | 127/10000 [00:24<31:14,  5.27step/s, loss=0.139401, elapsed=0.4min]
# Entraînement:   1%|▏         | 128/10000 [00:24<31:12,  5.27step/s, loss=0.139401, elapsed=0.4min]
# Entraînement:   1%|▏         | 128/10000 [00:24<31:12,  5.27step/s, loss=0.079691, elapsed=0.4min]
# Entraînement:   1%|▏         | 129/10000 [00:24<31:15,  5.26step/s, loss=0.079691, elapsed=0.4min]
# Entraînement:   1%|▏         | 129/10000 [00:24<31:15,  5.26step/s, loss=0.063044, elapsed=0.4min]
# Entraînement:   1%|▏         | 130/10000 [00:24<31:15,  5.26step/s, loss=0.063044, elapsed=0.4min]
# Entraînement:   1%|▏         | 130/10000 [00:24<31:15,  5.26step/s, loss=0.237298, elapsed=0.4min]
# Entraînement:   1%|▏         | 131/10000 [00:25<31:15,  5.26step/s, loss=0.237298, elapsed=0.4min]
# Entraînement:   1%|▏         | 131/10000 [00:25<31:15,  5.26step/s, loss=0.066279, elapsed=0.4min]
# Entraînement:   1%|▏         | 132/10000 [00:25<31:12,  5.27step/s, loss=0.066279, elapsed=0.4min]
# Entraînement:   1%|▏         | 132/10000 [00:25<31:12,  5.27step/s, loss=0.156102, elapsed=0.4min]
# Entraînement:   1%|▏         | 133/10000 [00:25<31:14,  5.26step/s, loss=0.156102, elapsed=0.4min]
# Entraînement:   1%|▏         | 133/10000 [00:25<31:14,  5.26step/s, loss=0.102715, elapsed=0.4min]
# Entraînement:   1%|▏         | 134/10000 [00:25<31:14,  5.26step/s, loss=0.102715, elapsed=0.4min]
# Entraînement:   1%|▏         | 134/10000 [00:25<31:14,  5.26step/s, loss=0.204130, elapsed=0.4min]
# Entraînement:   1%|▏         | 135/10000 [00:25<31:18,  5.25step/s, loss=0.204130, elapsed=0.4min]
# Entraînement:   1%|▏         | 135/10000 [00:25<31:18,  5.25step/s, loss=0.093987, elapsed=0.4min]
# Entraînement:   1%|▏         | 136/10000 [00:26<31:17,  5.25step/s, loss=0.093987, elapsed=0.4min]
# Entraînement:   1%|▏         | 136/10000 [00:26<31:17,  5.25step/s, loss=0.083681, elapsed=0.4min]
# Entraînement:   1%|▏         | 137/10000 [00:26<31:17,  5.25step/s, loss=0.083681, elapsed=0.4min]
# Entraînement:   1%|▏         | 137/10000 [00:26<31:17,  5.25step/s, loss=0.122501, elapsed=0.4min]
# Entraînement:   1%|▏         | 138/10000 [00:26<31:15,  5.26step/s, loss=0.122501, elapsed=0.4min]
# Entraînement:   1%|▏         | 138/10000 [00:26<31:15,  5.26step/s, loss=0.168299, elapsed=0.4min]
# Entraînement:   1%|▏         | 139/10000 [00:26<31:09,  5.27step/s, loss=0.168299, elapsed=0.4min]
# Entraînement:   1%|▏         | 139/10000 [00:26<31:09,  5.27step/s, loss=0.464212, elapsed=0.4min]
# Entraînement:   1%|▏         | 140/10000 [00:26<31:08,  5.28step/s, loss=0.464212, elapsed=0.4min]
# Entraînement:   1%|▏         | 140/10000 [00:26<31:08,  5.28step/s, loss=0.176872, elapsed=0.4min]
# Entraînement:   1%|▏         | 141/10000 [00:27<31:05,  5.28step/s, loss=0.176872, elapsed=0.4min]
# Entraînement:   1%|▏         | 141/10000 [00:27<31:05,  5.28step/s, loss=0.101435, elapsed=0.5min]
# Entraînement:   1%|▏         | 142/10000 [00:27<31:02,  5.29step/s, loss=0.101435, elapsed=0.5min]
# Entraînement:   1%|▏         | 142/10000 [00:27<31:02,  5.29step/s, loss=0.195171, elapsed=0.5min]
# Entraînement:   1%|▏         | 143/10000 [00:27<31:05,  5.28step/s, loss=0.195171, elapsed=0.5min]
# Entraînement:   1%|▏         | 143/10000 [00:27<31:05,  5.28step/s, loss=0.100086, elapsed=0.5min]
# Entraînement:   1%|▏         | 144/10000 [00:27<31:07,  5.28step/s, loss=0.100086, elapsed=0.5min]
# Entraînement:   1%|▏         | 144/10000 [00:27<31:07,  5.28step/s, loss=0.165663, elapsed=0.5min]
# Entraînement:   1%|▏         | 145/10000 [00:27<31:10,  5.27step/s, loss=0.165663, elapsed=0.5min]
# Entraînement:   1%|▏         | 145/10000 [00:27<31:10,  5.27step/s, loss=0.077342, elapsed=0.5min]
# Entraînement:   1%|▏         | 146/10000 [00:28<31:15,  5.26step/s, loss=0.077342, elapsed=0.5min]
# Entraînement:   1%|▏         | 146/10000 [00:28<31:15,  5.26step/s, loss=0.178918, elapsed=0.5min]
# Entraînement:   1%|▏         | 147/10000 [00:28<31:14,  5.26step/s, loss=0.178918, elapsed=0.5min]
# Entraînement:   1%|▏         | 147/10000 [00:28<31:14,  5.26step/s, loss=0.141889, elapsed=0.5min]
# Entraînement:   1%|▏         | 148/10000 [00:28<31:18,  5.25step/s, loss=0.141889, elapsed=0.5min]
# Entraînement:   1%|▏         | 148/10000 [00:28<31:18,  5.25step/s, loss=0.109427, elapsed=0.5min]
# Entraînement:   1%|▏         | 149/10000 [00:28<31:18,  5.24step/s, loss=0.109427, elapsed=0.5min]
# Entraînement:   1%|▏         | 149/10000 [00:28<31:18,  5.24step/s, loss=0.115139, elapsed=0.5min]
# Entraînement:   2%|▏         | 150/10000 [00:28<31:17,  5.25step/s, loss=0.115139, elapsed=0.5min]
# Entraînement:   2%|▏         | 150/10000 [00:28<31:17,  5.25step/s, loss=0.110744, elapsed=0.5min]
# Entraînement:   2%|▏         | 151/10000 [00:28<31:14,  5.25step/s, loss=0.110744, elapsed=0.5min]
# Entraînement:   2%|▏         | 151/10000 [00:28<31:14,  5.25step/s, loss=0.142252, elapsed=0.5min]
# Entraînement:   2%|▏         | 152/10000 [00:29<31:21,  5.23step/s, loss=0.142252, elapsed=0.5min]
# Entraînement:   2%|▏         | 152/10000 [00:29<31:21,  5.23step/s, loss=0.076453, elapsed=0.5min]
# Entraînement:   2%|▏         | 153/10000 [00:29<31:22,  5.23step/s, loss=0.076453, elapsed=0.5min]
# Entraînement:   2%|▏         | 153/10000 [00:29<31:22,  5.23step/s, loss=0.086869, elapsed=0.5min]
# Entraînement:   2%|▏         | 154/10000 [00:29<31:21,  5.23step/s, loss=0.086869, elapsed=0.5min]
# Entraînement:   2%|▏         | 154/10000 [00:29<31:21,  5.23step/s, loss=0.068711, elapsed=0.5min]
# Entraînement:   2%|▏         | 155/10000 [00:29<31:19,  5.24step/s, loss=0.068711, elapsed=0.5min]
# Entraînement:   2%|▏         | 155/10000 [00:29<31:19,  5.24step/s, loss=0.098141, elapsed=0.5min]
# Entraînement:   2%|▏         | 156/10000 [00:29<31:17,  5.24step/s, loss=0.098141, elapsed=0.5min]
# Entraînement:   2%|▏         | 156/10000 [00:29<31:17,  5.24step/s, loss=0.201934, elapsed=0.5min]
# Entraînement:   2%|▏         | 157/10000 [00:30<31:12,  5.26step/s, loss=0.201934, elapsed=0.5min]
# Entraînement:   2%|▏         | 157/10000 [00:30<31:12,  5.26step/s, loss=0.197012, elapsed=0.5min]
# Entraînement:   2%|▏         | 158/10000 [00:30<31:21,  5.23step/s, loss=0.197012, elapsed=0.5min]
# Entraînement:   2%|▏         | 158/10000 [00:30<31:21,  5.23step/s, loss=0.103072, elapsed=0.5min]
# Entraînement:   2%|▏         | 159/10000 [00:30<31:17,  5.24step/s, loss=0.103072, elapsed=0.5min]
# Entraînement:   2%|▏         | 159/10000 [00:30<31:17,  5.24step/s, loss=0.085754, elapsed=0.5min]
# Entraînement:   2%|▏         | 160/10000 [00:30<31:14,  5.25step/s, loss=0.085754, elapsed=0.5min]
# Entraînement:   2%|▏         | 160/10000 [00:30<31:14,  5.25step/s, loss=0.155538, elapsed=0.5min]
# Entraînement:   2%|▏         | 161/10000 [00:30<31:11,  5.26step/s, loss=0.155538, elapsed=0.5min]
# Entraînement:   2%|▏         | 161/10000 [00:30<31:11,  5.26step/s, loss=0.108626, elapsed=0.5min]
# Entraînement:   2%|▏         | 162/10000 [00:31<31:04,  5.28step/s, loss=0.108626, elapsed=0.5min]
# Entraînement:   2%|▏         | 162/10000 [00:31<31:04,  5.28step/s, loss=0.075497, elapsed=0.5min]
# Entraînement:   2%|▏         | 163/10000 [00:31<31:09,  5.26step/s, loss=0.075497, elapsed=0.5min]
# Entraînement:   2%|▏         | 163/10000 [00:31<31:09,  5.26step/s, loss=0.086715, elapsed=0.5min]
# Entraînement:   2%|▏         | 164/10000 [00:31<31:05,  5.27step/s, loss=0.086715, elapsed=0.5min]
# Entraînement:   2%|▏         | 164/10000 [00:31<31:05,  5.27step/s, loss=0.096868, elapsed=0.5min]
# Entraînement:   2%|▏         | 165/10000 [00:31<31:15,  5.24step/s, loss=0.096868, elapsed=0.5min]
# Entraînement:   2%|▏         | 165/10000 [00:31<31:15,  5.24step/s, loss=0.182538, elapsed=0.5min]
# Entraînement:   2%|▏         | 166/10000 [00:31<31:16,  5.24step/s, loss=0.182538, elapsed=0.5min]
# Entraînement:   2%|▏         | 166/10000 [00:31<31:16,  5.24step/s, loss=0.109980, elapsed=0.5min]
# Entraînement:   2%|▏         | 167/10000 [00:32<31:16,  5.24step/s, loss=0.109980, elapsed=0.5min]
# Entraînement:   2%|▏         | 167/10000 [00:32<31:16,  5.24step/s, loss=0.101268, elapsed=0.5min]
# Entraînement:   2%|▏         | 168/10000 [00:32<31:21,  5.23step/s, loss=0.101268, elapsed=0.5min]
# Entraînement:   2%|▏         | 168/10000 [00:32<31:21,  5.23step/s, loss=0.078884, elapsed=0.5min]
# Entraînement:   2%|▏         | 169/10000 [00:32<31:13,  5.25step/s, loss=0.078884, elapsed=0.5min]
# Entraînement:   2%|▏         | 169/10000 [00:32<31:13,  5.25step/s, loss=0.266105, elapsed=0.5min]
# Entraînement:   2%|▏         | 170/10000 [00:32<31:20,  5.23step/s, loss=0.266105, elapsed=0.5min]
# Entraînement:   2%|▏         | 170/10000 [00:32<31:20,  5.23step/s, loss=0.104680, elapsed=0.5min]
# Entraînement:   2%|▏         | 171/10000 [00:32<31:16,  5.24step/s, loss=0.104680, elapsed=0.5min]
# Entraînement:   2%|▏         | 171/10000 [00:32<31:16,  5.24step/s, loss=0.062601, elapsed=0.5min]
# Entraînement:   2%|▏         | 172/10000 [00:32<31:14,  5.24step/s, loss=0.062601, elapsed=0.5min]
# Entraînement:   2%|▏         | 172/10000 [00:32<31:14,  5.24step/s, loss=0.079410, elapsed=0.5min]
# Entraînement:   2%|▏         | 173/10000 [00:33<31:11,  5.25step/s, loss=0.079410, elapsed=0.5min]
# Entraînement:   2%|▏         | 173/10000 [00:33<31:11,  5.25step/s, loss=0.104996, elapsed=0.6min]
# Entraînement:   2%|▏         | 174/10000 [00:33<31:07,  5.26step/s, loss=0.104996, elapsed=0.6min]
# Entraînement:   2%|▏         | 174/10000 [00:33<31:07,  5.26step/s, loss=0.161709, elapsed=0.6min]
# Entraînement:   2%|▏         | 175/10000 [00:33<31:10,  5.25step/s, loss=0.161709, elapsed=0.6min]
# Entraînement:   2%|▏         | 175/10000 [00:33<31:10,  5.25step/s, loss=0.115320, elapsed=0.6min]
# Entraînement:   2%|▏         | 176/10000 [00:33<31:11,  5.25step/s, loss=0.115320, elapsed=0.6min]
# Entraînement:   2%|▏         | 176/10000 [00:33<31:11,  5.25step/s, loss=0.118871, elapsed=0.6min]
# Entraînement:   2%|▏         | 177/10000 [00:33<31:07,  5.26step/s, loss=0.118871, elapsed=0.6min]
# Entraînement:   2%|▏         | 177/10000 [00:33<31:07,  5.26step/s, loss=0.071876, elapsed=0.6min]
# Entraînement:   2%|▏         | 178/10000 [00:34<31:15,  5.24step/s, loss=0.071876, elapsed=0.6min]
# Entraînement:   2%|▏         | 178/10000 [00:34<31:15,  5.24step/s, loss=0.074122, elapsed=0.6min]
# Entraînement:   2%|▏         | 179/10000 [00:34<31:10,  5.25step/s, loss=0.074122, elapsed=0.6min]
# Entraînement:   2%|▏         | 179/10000 [00:34<31:10,  5.25step/s, loss=0.097835, elapsed=0.6min]
# Entraînement:   2%|▏         | 180/10000 [00:34<31:05,  5.26step/s, loss=0.097835, elapsed=0.6min]
# Entraînement:   2%|▏         | 180/10000 [00:34<31:05,  5.26step/s, loss=0.119539, elapsed=0.6min]
# Entraînement:   2%|▏         | 181/10000 [00:34<31:04,  5.26step/s, loss=0.119539, elapsed=0.6min]
# Entraînement:   2%|▏         | 181/10000 [00:34<31:04,  5.26step/s, loss=0.072175, elapsed=0.6min]
# Entraînement:   2%|▏         | 182/10000 [00:34<31:03,  5.27step/s, loss=0.072175, elapsed=0.6min]
# Entraînement:   2%|▏         | 182/10000 [00:34<31:03,  5.27step/s, loss=0.122064, elapsed=0.6min]
# Entraînement:   2%|▏         | 183/10000 [00:35<31:00,  5.28step/s, loss=0.122064, elapsed=0.6min]
# Entraînement:   2%|▏         | 183/10000 [00:35<31:00,  5.28step/s, loss=0.163080, elapsed=0.6min]
# Entraînement:   2%|▏         | 184/10000 [00:35<31:10,  5.25step/s, loss=0.163080, elapsed=0.6min]
# Entraînement:   2%|▏         | 184/10000 [00:35<31:10,  5.25step/s, loss=0.086118, elapsed=0.6min]
# Entraînement:   2%|▏         | 185/10000 [00:35<31:05,  5.26step/s, loss=0.086118, elapsed=0.6min]
# Entraînement:   2%|▏         | 185/10000 [00:35<31:05,  5.26step/s, loss=0.085259, elapsed=0.6min]
# Entraînement:   2%|▏         | 186/10000 [00:35<30:59,  5.28step/s, loss=0.085259, elapsed=0.6min]
# Entraînement:   2%|▏         | 186/10000 [00:35<30:59,  5.28step/s, loss=0.054105, elapsed=0.6min]
# Entraînement:   2%|▏         | 187/10000 [00:35<30:57,  5.28step/s, loss=0.054105, elapsed=0.6min]
# Entraînement:   2%|▏         | 187/10000 [00:35<30:57,  5.28step/s, loss=0.074453, elapsed=0.6min]
# Entraînement:   2%|▏         | 188/10000 [00:36<30:57,  5.28step/s, loss=0.074453, elapsed=0.6min]
# Entraînement:   2%|▏         | 188/10000 [00:36<30:57,  5.28step/s, loss=0.097529, elapsed=0.6min]
# Entraînement:   2%|▏         | 189/10000 [00:36<30:57,  5.28step/s, loss=0.097529, elapsed=0.6min]
# Entraînement:   2%|▏         | 189/10000 [00:36<30:57,  5.28step/s, loss=0.188931, elapsed=0.6min]
# Entraînement:   2%|▏         | 190/10000 [00:36<30:54,  5.29step/s, loss=0.188931, elapsed=0.6min]
# Entraînement:   2%|▏         | 190/10000 [00:36<30:54,  5.29step/s, loss=0.261334, elapsed=0.6min]
# Entraînement:   2%|▏         | 191/10000 [00:36<30:53,  5.29step/s, loss=0.261334, elapsed=0.6min]
# Entraînement:   2%|▏         | 191/10000 [00:36<30:53,  5.29step/s, loss=0.125767, elapsed=0.6min]
# Entraînement:   2%|▏         | 192/10000 [00:36<30:52,  5.29step/s, loss=0.125767, elapsed=0.6min]
# Entraînement:   2%|▏         | 192/10000 [00:36<30:52,  5.29step/s, loss=0.318732, elapsed=0.6min]
# Entraînement:   2%|▏         | 193/10000 [00:36<30:56,  5.28step/s, loss=0.318732, elapsed=0.6min]
# Entraînement:   2%|▏         | 193/10000 [00:36<30:56,  5.28step/s, loss=0.068080, elapsed=0.6min]
# Entraînement:   2%|▏         | 194/10000 [00:37<30:57,  5.28step/s, loss=0.068080, elapsed=0.6min]
# Entraînement:   2%|▏         | 194/10000 [00:37<30:57,  5.28step/s, loss=0.137315, elapsed=0.6min]
# Entraînement:   2%|▏         | 195/10000 [00:37<30:57,  5.28step/s, loss=0.137315, elapsed=0.6min]
# Entraînement:   2%|▏         | 195/10000 [00:37<30:57,  5.28step/s, loss=0.271421, elapsed=0.6min]
# Entraînement:   2%|▏         | 196/10000 [00:37<30:57,  5.28step/s, loss=0.271421, elapsed=0.6min]
# Entraînement:   2%|▏         | 196/10000 [00:37<30:57,  5.28step/s, loss=0.108242, elapsed=0.6min]
# Entraînement:   2%|▏         | 197/10000 [00:37<30:56,  5.28step/s, loss=0.108242, elapsed=0.6min]
# Entraînement:   2%|▏         | 197/10000 [00:37<30:56,  5.28step/s, loss=0.091824, elapsed=0.6min]
# Entraînement:   2%|▏         | 198/10000 [00:37<30:55,  5.28step/s, loss=0.091824, elapsed=0.6min]
# Entraînement:   2%|▏         | 198/10000 [00:37<30:55,  5.28step/s, loss=0.079683, elapsed=0.6min]
# Entraînement:   2%|▏         | 199/10000 [00:38<30:55,  5.28step/s, loss=0.079683, elapsed=0.6min]
# Entraînement:   2%|▏         | 199/10000 [00:38<30:55,  5.28step/s, loss=0.059055, elapsed=0.6min]
# Entraînement:   2%|▏         | 200/10000 [00:38<30:55,  5.28step/s, loss=0.059055, elapsed=0.6min]
# Entraînement:   2%|▏         | 200/10000 [00:38<30:55,  5.28step/s, loss=0.070913, elapsed=0.6min]
# Entraînement:   2%|▏         | 200/10000 [00:38<30:55,  5.28step/s, loss=0.070913, elapsed=0.6min]
# Entraînement:   2%|▏         | 201/10000 [00:38<31:10,  5.24step/s, loss=0.070913, elapsed=0.6min]
# Entraînement:   2%|▏         | 201/10000 [00:38<31:10,  5.24step/s, loss=0.118390, elapsed=0.6min]
# Step 200/10000 | Train loss: 0.070913 | Elapsed: 0.6min | ETA: 31.3min
# Entraînement:   2%|▏         | 202/10000 [00:38<31:06,  5.25step/s, loss=0.118390, elapsed=0.6min]
# Entraînement:   2%|▏         | 202/10000 [00:38<31:06,  5.25step/s, loss=0.100735, elapsed=0.6min]
# Entraînement:   2%|▏         | 203/10000 [00:38<31:04,  5.26step/s, loss=0.100735, elapsed=0.6min]
# Entraînement:   2%|▏         | 203/10000 [00:38<31:04,  5.26step/s, loss=0.165837, elapsed=0.6min]
# Entraînement:   2%|▏         | 204/10000 [00:39<31:01,  5.26step/s, loss=0.165837, elapsed=0.6min]
# Entraînement:   2%|▏         | 204/10000 [00:39<31:01,  5.26step/s, loss=0.102410, elapsed=0.7min]
# Entraînement:   2%|▏         | 205/10000 [00:39<31:01,  5.26step/s, loss=0.102410, elapsed=0.7min]
# Entraînement:   2%|▏         | 205/10000 [00:39<31:01,  5.26step/s, loss=0.089774, elapsed=0.7min]
# Entraînement:   2%|▏         | 206/10000 [00:39<31:01,  5.26step/s, loss=0.089774, elapsed=0.7min]
# Entraînement:   2%|▏         | 206/10000 [00:39<31:01,  5.26step/s, loss=0.209694, elapsed=0.7min]
# Entraînement:   2%|▏         | 207/10000 [00:39<30:58,  5.27step/s, loss=0.209694, elapsed=0.7min]
# Entraînement:   2%|▏         | 207/10000 [00:39<30:58,  5.27step/s, loss=0.061286, elapsed=0.7min]
# Entraînement:   2%|▏         | 208/10000 [00:39<30:55,  5.28step/s, loss=0.061286, elapsed=0.7min]
# Entraînement:   2%|▏         | 208/10000 [00:39<30:55,  5.28step/s, loss=0.066987, elapsed=0.7min]
# Entraînement:   2%|▏         | 209/10000 [00:39<30:58,  5.27step/s, loss=0.066987, elapsed=0.7min]
# Entraînement:   2%|▏         | 209/10000 [00:39<30:58,  5.27step/s, loss=0.068501, elapsed=0.7min]
# Entraînement:   2%|▏         | 210/10000 [00:40<31:04,  5.25step/s, loss=0.068501, elapsed=0.7min]
# Entraînement:   2%|▏         | 210/10000 [00:40<31:04,  5.25step/s, loss=0.118468, elapsed=0.7min]
# Entraînement:   2%|▏         | 211/10000 [00:40<31:03,  5.25step/s, loss=0.118468, elapsed=0.7min]
# Entraînement:   2%|▏         | 211/10000 [00:40<31:03,  5.25step/s, loss=0.126269, elapsed=0.7min]
# Entraînement:   2%|▏         | 212/10000 [00:40<31:03,  5.25step/s, loss=0.126269, elapsed=0.7min]
# Entraînement:   2%|▏         | 212/10000 [00:40<31:03,  5.25step/s, loss=0.107738, elapsed=0.7min]
# Entraînement:   2%|▏         | 213/10000 [00:40<31:01,  5.26step/s, loss=0.107738, elapsed=0.7min]
# Entraînement:   2%|▏         | 213/10000 [00:40<31:01,  5.26step/s, loss=0.102978, elapsed=0.7min]
# Entraînement:   2%|▏         | 214/10000 [00:40<30:58,  5.27step/s, loss=0.102978, elapsed=0.7min]
# Entraînement:   2%|▏         | 214/10000 [00:40<30:58,  5.27step/s, loss=0.105463, elapsed=0.7min]
# Entraînement:   2%|▏         | 215/10000 [00:41<30:55,  5.27step/s, loss=0.105463, elapsed=0.7min]
# Entraînement:   2%|▏         | 215/10000 [00:41<30:55,  5.27step/s, loss=0.101174, elapsed=0.7min]
# Entraînement:   2%|▏         | 216/10000 [00:41<30:52,  5.28step/s, loss=0.101174, elapsed=0.7min]
# Entraînement:   2%|▏         | 216/10000 [00:41<30:52,  5.28step/s, loss=0.069771, elapsed=0.7min]
# Entraînement:   2%|▏         | 217/10000 [00:41<30:51,  5.28step/s, loss=0.069771, elapsed=0.7min]
# Entraînement:   2%|▏         | 217/10000 [00:41<30:51,  5.28step/s, loss=0.123549, elapsed=0.7min]
# Entraînement:   2%|▏         | 218/10000 [00:41<30:50,  5.29step/s, loss=0.123549, elapsed=0.7min]
# Entraînement:   2%|▏         | 218/10000 [00:41<30:50,  5.29step/s, loss=0.145500, elapsed=0.7min]
# Entraînement:   2%|▏         | 219/10000 [00:41<30:54,  5.28step/s, loss=0.145500, elapsed=0.7min]
# Entraînement:   2%|▏         | 219/10000 [00:41<30:54,  5.28step/s, loss=0.108631, elapsed=0.7min]
# Entraînement:   2%|▏         | 220/10000 [00:42<30:56,  5.27step/s, loss=0.108631, elapsed=0.7min]
# Entraînement:   2%|▏         | 220/10000 [00:42<30:56,  5.27step/s, loss=0.077629, elapsed=0.7min]
# Entraînement:   2%|▏         | 221/10000 [00:42<30:50,  5.28step/s, loss=0.077629, elapsed=0.7min]
# Entraînement:   2%|▏         | 221/10000 [00:42<30:50,  5.28step/s, loss=0.190467, elapsed=0.7min]
# Entraînement:   2%|▏         | 222/10000 [00:42<30:54,  5.27step/s, loss=0.190467, elapsed=0.7min]
# Entraînement:   2%|▏         | 222/10000 [00:42<30:54,  5.27step/s, loss=0.197220, elapsed=0.7min]
# Entraînement:   2%|▏         | 223/10000 [00:42<30:52,  5.28step/s, loss=0.197220, elapsed=0.7min]
# Entraînement:   2%|▏         | 223/10000 [00:42<30:52,  5.28step/s, loss=0.085346, elapsed=0.7min]
# Entraînement:   2%|▏         | 224/10000 [00:42<30:54,  5.27step/s, loss=0.085346, elapsed=0.7min]
# Entraînement:   2%|▏         | 224/10000 [00:42<30:54,  5.27step/s, loss=0.108879, elapsed=0.7min]
# Entraînement:   2%|▏         | 225/10000 [00:43<30:53,  5.27step/s, loss=0.108879, elapsed=0.7min]
# Entraînement:   2%|▏         | 225/10000 [00:43<30:53,  5.27step/s, loss=0.073296, elapsed=0.7min]
# Entraînement:   2%|▏         | 226/10000 [00:43<30:57,  5.26step/s, loss=0.073296, elapsed=0.7min]
# Entraînement:   2%|▏         | 226/10000 [00:43<30:57,  5.26step/s, loss=0.097343, elapsed=0.7min]
# Entraînement:   2%|▏         | 227/10000 [00:43<30:58,  5.26step/s, loss=0.097343, elapsed=0.7min]
# Entraînement:   2%|▏         | 227/10000 [00:43<30:58,  5.26step/s, loss=0.162189, elapsed=0.7min]
# Entraînement:   2%|▏         | 228/10000 [00:43<30:59,  5.26step/s, loss=0.162189, elapsed=0.7min]
# Entraînement:   2%|▏         | 228/10000 [00:43<30:59,  5.26step/s, loss=0.165109, elapsed=0.7min]
# Entraînement:   2%|▏         | 229/10000 [00:43<30:57,  5.26step/s, loss=0.165109, elapsed=0.7min]
# Entraînement:   2%|▏         | 229/10000 [00:43<30:57,  5.26step/s, loss=0.078527, elapsed=0.7min]
# Entraînement:   2%|▏         | 230/10000 [00:43<30:55,  5.26step/s, loss=0.078527, elapsed=0.7min]
# Entraînement:   2%|▏         | 230/10000 [00:43<30:55,  5.26step/s, loss=0.065861, elapsed=0.7min]
# Entraînement:   2%|▏         | 231/10000 [00:44<30:54,  5.27step/s, loss=0.065861, elapsed=0.7min]
# Entraînement:   2%|▏         | 231/10000 [00:44<30:54,  5.27step/s, loss=0.060814, elapsed=0.7min]
# Entraînement:   2%|▏         | 232/10000 [00:44<30:52,  5.27step/s, loss=0.060814, elapsed=0.7min]
# Entraînement:   2%|▏         | 232/10000 [00:44<30:52,  5.27step/s, loss=0.075203, elapsed=0.7min]
# Entraînement:   2%|▏         | 233/10000 [00:44<30:48,  5.28step/s, loss=0.075203, elapsed=0.7min]
# Entraînement:   2%|▏         | 233/10000 [00:44<30:48,  5.28step/s, loss=0.069280, elapsed=0.7min]
# Entraînement:   2%|▏         | 234/10000 [00:44<30:49,  5.28step/s, loss=0.069280, elapsed=0.7min]
# Entraînement:   2%|▏         | 234/10000 [00:44<30:49,  5.28step/s, loss=0.089056, elapsed=0.7min]
# Entraînement:   2%|▏         | 235/10000 [00:44<30:51,  5.28step/s, loss=0.089056, elapsed=0.7min]
# Entraînement:   2%|▏         | 235/10000 [00:44<30:51,  5.28step/s, loss=0.099741, elapsed=0.7min]
# Entraînement:   2%|▏         | 236/10000 [00:45<30:51,  5.27step/s, loss=0.099741, elapsed=0.7min]
# Entraînement:   2%|▏         | 236/10000 [00:45<30:51,  5.27step/s, loss=0.093887, elapsed=0.8min]
# Entraînement:   2%|▏         | 237/10000 [00:45<30:51,  5.27step/s, loss=0.093887, elapsed=0.8min]
# Entraînement:   2%|▏         | 237/10000 [00:45<30:51,  5.27step/s, loss=0.078703, elapsed=0.8min]
# Entraînement:   2%|▏         | 238/10000 [00:45<30:47,  5.29step/s, loss=0.078703, elapsed=0.8min]
# Entraînement:   2%|▏         | 238/10000 [00:45<30:47,  5.29step/s, loss=0.049850, elapsed=0.8min]
# Entraînement:   2%|▏         | 239/10000 [00:45<30:48,  5.28step/s, loss=0.049850, elapsed=0.8min]
# Entraînement:   2%|▏         | 239/10000 [00:45<30:48,  5.28step/s, loss=0.105609, elapsed=0.8min]
# Entraînement:   2%|▏         | 240/10000 [00:45<30:45,  5.29step/s, loss=0.105609, elapsed=0.8min]
# Entraînement:   2%|▏         | 240/10000 [00:45<30:45,  5.29step/s, loss=0.046082, elapsed=0.8min]
# Entraînement:   2%|▏         | 241/10000 [00:46<30:42,  5.30step/s, loss=0.046082, elapsed=0.8min]
# Entraînement:   2%|▏         | 241/10000 [00:46<30:42,  5.30step/s, loss=0.052645, elapsed=0.8min]
# ...
# Entraînement:  97%|█████████▋| 9676/10000 [31:00<01:01,  5.28step/s, loss=0.145652, elapsed=31.0min]
# Entraînement:  97%|█████████▋| 9676/10000 [31:00<01:01,  5.28step/s, loss=0.018076, elapsed=31.0min]
# Entraînement:  97%|█████████▋| 9677/10000 [31:00<01:01,  5.27step/s, loss=0.018076, elapsed=31.0min]
# Entraînement:  97%|█████████▋| 9677/10000 [31:00<01:01,  5.27step/s, loss=0.015336, elapsed=31.0min]
# Entraînement:  97%|█████████▋| 9678/10000 [31:00<01:01,  5.28step/s, loss=0.015336, elapsed=31.0min]
# Entraînement:  97%|█████████▋| 9678/10000 [31:00<01:01,  5.28step/s, loss=0.017510, elapsed=31.0min]
# Entraînement:  97%|█████████▋| 9679/10000 [31:00<01:00,  5.29step/s, loss=0.017510, elapsed=31.0min]
# Entraînement:  97%|█████████▋| 9679/10000 [31:00<01:00,  5.29step/s, loss=0.043235, elapsed=31.0min]
# Entraînement:  97%|█████████▋| 9680/10000 [31:00<01:00,  5.28step/s, loss=0.043235, elapsed=31.0min]
# Entraînement:  97%|█████████▋| 9680/10000 [31:00<01:00,  5.28step/s, loss=0.037758, elapsed=31.0min]
# Entraînement:  97%|█████████▋| 9681/10000 [31:01<01:00,  5.28step/s, loss=0.037758, elapsed=31.0min]
# Entraînement:  97%|█████████▋| 9681/10000 [31:01<01:00,  5.28step/s, loss=0.067671, elapsed=31.0min]
# Entraînement:  97%|█████████▋| 9682/10000 [31:01<01:00,  5.28step/s, loss=0.067671, elapsed=31.0min]
# Entraînement:  97%|█████████▋| 9682/10000 [31:01<01:00,  5.28step/s, loss=0.053448, elapsed=31.0min]
# Entraînement:  97%|█████████▋| 9683/10000 [31:01<00:59,  5.28step/s, loss=0.053448, elapsed=31.0min]
# Entraînement:  97%|█████████▋| 9683/10000 [31:01<00:59,  5.28step/s, loss=0.035623, elapsed=31.0min]
# Entraînement:  97%|█████████▋| 9684/10000 [31:01<00:59,  5.29step/s, loss=0.035623, elapsed=31.0min]
# Entraînement:  97%|█████████▋| 9684/10000 [31:01<00:59,  5.29step/s, loss=0.044303, elapsed=31.0min]
# Entraînement:  97%|█████████▋| 9685/10000 [31:01<00:59,  5.29step/s, loss=0.044303, elapsed=31.0min]
# Entraînement:  97%|█████████▋| 9685/10000 [31:01<00:59,  5.29step/s, loss=0.026967, elapsed=31.0min]
# Entraînement:  97%|█████████▋| 9686/10000 [31:02<00:59,  5.30step/s, loss=0.026967, elapsed=31.0min]
# Entraînement:  97%|█████████▋| 9686/10000 [31:02<00:59,  5.30step/s, loss=0.051012, elapsed=31.0min]
# Entraînement:  97%|█████████▋| 9687/10000 [31:02<00:59,  5.30step/s, loss=0.051012, elapsed=31.0min]
# Entraînement:  97%|█████████▋| 9687/10000 [31:02<00:59,  5.30step/s, loss=0.111972, elapsed=31.0min]
# Entraînement:  97%|█████████▋| 9688/10000 [31:02<00:58,  5.30step/s, loss=0.111972, elapsed=31.0min]
# Entraînement:  97%|█████████▋| 9688/10000 [31:02<00:58,  5.30step/s, loss=0.033889, elapsed=31.0min]
# Entraînement:  97%|█████████▋| 9689/10000 [31:02<00:58,  5.28step/s, loss=0.033889, elapsed=31.0min]
# Entraînement:  97%|█████████▋| 9689/10000 [31:02<00:58,  5.28step/s, loss=0.023643, elapsed=31.0min]
# Entraînement:  97%|█████████▋| 9690/10000 [31:02<00:58,  5.28step/s, loss=0.023643, elapsed=31.0min]
# Entraînement:  97%|█████████▋| 9690/10000 [31:02<00:58,  5.28step/s, loss=0.121460, elapsed=31.0min]
# Entraînement:  97%|█████████▋| 9691/10000 [31:03<00:58,  5.29step/s, loss=0.121460, elapsed=31.0min]
# Entraînement:  97%|█████████▋| 9691/10000 [31:03<00:58,  5.29step/s, loss=0.043876, elapsed=31.1min]
# Entraînement:  97%|█████████▋| 9692/10000 [31:03<00:58,  5.28step/s, loss=0.043876, elapsed=31.1min]
# Entraînement:  97%|█████████▋| 9692/10000 [31:03<00:58,  5.28step/s, loss=0.030360, elapsed=31.1min]
# Entraînement:  97%|█████████▋| 9693/10000 [31:03<00:58,  5.29step/s, loss=0.030360, elapsed=31.1min]
# Entraînement:  97%|█████████▋| 9693/10000 [31:03<00:58,  5.29step/s, loss=0.052504, elapsed=31.1min]
# Entraînement:  97%|█████████▋| 9694/10000 [31:03<00:57,  5.30step/s, loss=0.052504, elapsed=31.1min]
# Entraînement:  97%|█████████▋| 9694/10000 [31:03<00:57,  5.30step/s, loss=0.031039, elapsed=31.1min]
# Entraînement:  97%|█████████▋| 9695/10000 [31:03<00:57,  5.30step/s, loss=0.031039, elapsed=31.1min]
# Entraînement:  97%|█████████▋| 9695/10000 [31:03<00:57,  5.30step/s, loss=0.037705, elapsed=31.1min]
# Entraînement:  97%|█████████▋| 9696/10000 [31:03<00:57,  5.29step/s, loss=0.037705, elapsed=31.1min]
# Entraînement:  97%|█████████▋| 9696/10000 [31:03<00:57,  5.29step/s, loss=0.029783, elapsed=31.1min]
# Entraînement:  97%|█████████▋| 9697/10000 [31:04<00:57,  5.30step/s, loss=0.029783, elapsed=31.1min]
# Entraînement:  97%|█████████▋| 9697/10000 [31:04<00:57,  5.30step/s, loss=0.037763, elapsed=31.1min]
# Entraînement:  97%|█████████▋| 9698/10000 [31:04<00:57,  5.29step/s, loss=0.037763, elapsed=31.1min]
# Entraînement:  97%|█████████▋| 9698/10000 [31:04<00:57,  5.29step/s, loss=0.110041, elapsed=31.1min]
# Entraînement:  97%|█████████▋| 9699/10000 [31:04<00:56,  5.29step/s, loss=0.110041, elapsed=31.1min]
# Entraînement:  97%|█████████▋| 9699/10000 [31:04<00:56,  5.29step/s, loss=0.088406, elapsed=31.1min]
# Entraînement:  97%|█████████▋| 9700/10000 [31:04<00:56,  5.30step/s, loss=0.088406, elapsed=31.1min]
# Entraînement:  97%|█████████▋| 9700/10000 [31:04<00:56,  5.30step/s, loss=0.044265, elapsed=31.1min]
# Entraînement:  97%|█████████▋| 9700/10000 [31:04<00:56,  5.30step/s, loss=0.044265, elapsed=31.1min]
# Entraînement:  97%|█████████▋| 9701/10000 [31:04<00:56,  5.25step/s, loss=0.044265, elapsed=31.1min]
# Entraînement:  97%|█████████▋| 9701/10000 [31:04<00:56,  5.25step/s, loss=0.064405, elapsed=31.1min]
# Step 9700/10000 | Train loss: 0.044265 | Elapsed: 31.1min | ETA: 1.0min
# Entraînement:  97%|█████████▋| 9702/10000 [31:05<00:56,  5.27step/s, loss=0.064405, elapsed=31.1min]
# Entraînement:  97%|█████████▋| 9702/10000 [31:05<00:56,  5.27step/s, loss=0.024152, elapsed=31.1min]
# Entraînement:  97%|█████████▋| 9703/10000 [31:05<00:56,  5.28step/s, loss=0.024152, elapsed=31.1min]
# Entraînement:  97%|█████████▋| 9703/10000 [31:05<00:56,  5.28step/s, loss=0.031567, elapsed=31.1min]
# Entraînement:  97%|█████████▋| 9704/10000 [31:05<00:55,  5.29step/s, loss=0.031567, elapsed=31.1min]
# Entraînement:  97%|█████████▋| 9704/10000 [31:05<00:55,  5.29step/s, loss=0.037273, elapsed=31.1min]
# Entraînement:  97%|█████████▋| 9705/10000 [31:05<00:55,  5.28step/s, loss=0.037273, elapsed=31.1min]
# Entraînement:  97%|█████████▋| 9705/10000 [31:05<00:55,  5.28step/s, loss=0.037615, elapsed=31.1min]
# Entraînement:  97%|█████████▋| 9706/10000 [31:05<00:55,  5.29step/s, loss=0.037615, elapsed=31.1min]
# Entraînement:  97%|█████████▋| 9706/10000 [31:05<00:55,  5.29step/s, loss=0.034122, elapsed=31.1min]
# Entraînement:  97%|█████████▋| 9707/10000 [31:06<00:55,  5.29step/s, loss=0.034122, elapsed=31.1min]
# Entraînement:  97%|█████████▋| 9707/10000 [31:06<00:55,  5.29step/s, loss=0.064248, elapsed=31.1min]
# Entraînement:  97%|█████████▋| 9708/10000 [31:06<00:55,  5.29step/s, loss=0.064248, elapsed=31.1min]
# Entraînement:  97%|█████████▋| 9708/10000 [31:06<00:55,  5.29step/s, loss=0.027191, elapsed=31.1min]
# Entraînement:  97%|█████████▋| 9709/10000 [31:06<00:54,  5.29step/s, loss=0.027191, elapsed=31.1min]
# Entraînement:  97%|█████████▋| 9709/10000 [31:06<00:54,  5.29step/s, loss=0.030787, elapsed=31.1min]
# Entraînement:  97%|█████████▋| 9710/10000 [31:06<00:54,  5.29step/s, loss=0.030787, elapsed=31.1min]
# Entraînement:  97%|█████████▋| 9710/10000 [31:06<00:54,  5.29step/s, loss=0.123203, elapsed=31.1min]
# Entraînement:  97%|█████████▋| 9711/10000 [31:06<00:54,  5.30step/s, loss=0.123203, elapsed=31.1min]
# Entraînement:  97%|█████████▋| 9711/10000 [31:06<00:54,  5.30step/s, loss=0.092867, elapsed=31.1min]
# Entraînement:  97%|█████████▋| 9712/10000 [31:07<00:54,  5.29step/s, loss=0.092867, elapsed=31.1min]
# Entraînement:  97%|█████████▋| 9712/10000 [31:07<00:54,  5.29step/s, loss=0.017379, elapsed=31.1min]
# Entraînement:  97%|█████████▋| 9713/10000 [31:07<00:54,  5.28step/s, loss=0.017379, elapsed=31.1min]
# Entraînement:  97%|█████████▋| 9713/10000 [31:07<00:54,  5.28step/s, loss=0.055909, elapsed=31.1min]
# Entraînement:  97%|█████████▋| 9714/10000 [31:07<00:54,  5.28step/s, loss=0.055909, elapsed=31.1min]
# Entraînement:  97%|█████████▋| 9714/10000 [31:07<00:54,  5.28step/s, loss=0.027768, elapsed=31.1min]
# Entraînement:  97%|█████████▋| 9715/10000 [31:07<00:53,  5.28step/s, loss=0.027768, elapsed=31.1min]
# Entraînement:  97%|█████████▋| 9715/10000 [31:07<00:53,  5.28step/s, loss=0.028863, elapsed=31.1min]
# Entraînement:  97%|█████████▋| 9716/10000 [31:07<00:53,  5.28step/s, loss=0.028863, elapsed=31.1min]
# Entraînement:  97%|█████████▋| 9716/10000 [31:07<00:53,  5.28step/s, loss=0.056650, elapsed=31.1min]
# Entraînement:  97%|█████████▋| 9717/10000 [31:07<00:53,  5.29step/s, loss=0.056650, elapsed=31.1min]
# Entraînement:  97%|█████████▋| 9717/10000 [31:07<00:53,  5.29step/s, loss=0.044284, elapsed=31.1min]
# Entraînement:  97%|█████████▋| 9718/10000 [31:08<00:53,  5.29step/s, loss=0.044284, elapsed=31.1min]
# Entraînement:  97%|█████████▋| 9718/10000 [31:08<00:53,  5.29step/s, loss=0.056498, elapsed=31.1min]
# Entraînement:  97%|█████████▋| 9719/10000 [31:08<00:53,  5.30step/s, loss=0.056498, elapsed=31.1min]
# Entraînement:  97%|█████████▋| 9719/10000 [31:08<00:53,  5.30step/s, loss=0.034717, elapsed=31.1min]
# Entraînement:  97%|█████████▋| 9720/10000 [31:08<00:52,  5.30step/s, loss=0.034717, elapsed=31.1min]
# Entraînement:  97%|█████████▋| 9720/10000 [31:08<00:52,  5.30step/s, loss=0.042985, elapsed=31.1min]
# Entraînement:  97%|█████████▋| 9721/10000 [31:08<00:52,  5.29step/s, loss=0.042985, elapsed=31.1min]
# Entraînement:  97%|█████████▋| 9721/10000 [31:08<00:52,  5.29step/s, loss=0.016738, elapsed=31.1min]
# Entraînement:  97%|█████████▋| 9722/10000 [31:08<00:52,  5.27step/s, loss=0.016738, elapsed=31.1min]
# Entraînement:  97%|█████████▋| 9722/10000 [31:08<00:52,  5.27step/s, loss=0.033439, elapsed=31.1min]
# Entraînement:  97%|█████████▋| 9723/10000 [31:09<00:52,  5.27step/s, loss=0.033439, elapsed=31.1min]
# Entraînement:  97%|█████████▋| 9723/10000 [31:09<00:52,  5.27step/s, loss=0.031177, elapsed=31.2min]
# Entraînement:  97%|█████████▋| 9724/10000 [31:09<00:52,  5.27step/s, loss=0.031177, elapsed=31.2min]
# Entraînement:  97%|█████████▋| 9724/10000 [31:09<00:52,  5.27step/s, loss=0.063993, elapsed=31.2min]
# Entraînement:  97%|█████████▋| 9725/10000 [31:09<00:52,  5.27step/s, loss=0.063993, elapsed=31.2min]
# Entraînement:  97%|█████████▋| 9725/10000 [31:09<00:52,  5.27step/s, loss=0.025352, elapsed=31.2min]
# Entraînement:  97%|█████████▋| 9726/10000 [31:09<00:51,  5.28step/s, loss=0.025352, elapsed=31.2min]
# Entraînement:  97%|█████████▋| 9726/10000 [31:09<00:51,  5.28step/s, loss=0.038045, elapsed=31.2min]
# Entraînement:  97%|█████████▋| 9727/10000 [31:09<00:51,  5.29step/s, loss=0.038045, elapsed=31.2min]
# Entraînement:  97%|█████████▋| 9727/10000 [31:09<00:51,  5.29step/s, loss=0.053381, elapsed=31.2min]
# Entraînement:  97%|█████████▋| 9728/10000 [31:10<00:51,  5.30step/s, loss=0.053381, elapsed=31.2min]
# Entraînement:  97%|█████████▋| 9728/10000 [31:10<00:51,  5.30step/s, loss=0.031776, elapsed=31.2min]
# Entraînement:  97%|█████████▋| 9729/10000 [31:10<00:51,  5.29step/s, loss=0.031776, elapsed=31.2min]
# Entraînement:  97%|█████████▋| 9729/10000 [31:10<00:51,  5.29step/s, loss=0.034298, elapsed=31.2min]
# Entraînement:  97%|█████████▋| 9730/10000 [31:10<00:51,  5.28step/s, loss=0.034298, elapsed=31.2min]
# Entraînement:  97%|█████████▋| 9730/10000 [31:10<00:51,  5.28step/s, loss=0.047503, elapsed=31.2min]
# Entraînement:  97%|█████████▋| 9731/10000 [31:10<00:50,  5.28step/s, loss=0.047503, elapsed=31.2min]
# Entraînement:  97%|█████████▋| 9731/10000 [31:10<00:50,  5.28step/s, loss=0.034382, elapsed=31.2min]
# Entraînement:  97%|█████████▋| 9732/10000 [31:10<00:50,  5.30step/s, loss=0.034382, elapsed=31.2min]
# Entraînement:  97%|█████████▋| 9732/10000 [31:10<00:50,  5.30step/s, loss=0.043165, elapsed=31.2min]
# Entraînement:  97%|█████████▋| 9733/10000 [31:11<01:13,  3.62step/s, loss=0.043165, elapsed=31.2min]
# Entraînement:  97%|█████████▋| 9733/10000 [31:11<01:13,  3.62step/s, loss=0.032690, elapsed=31.2min]
# Entraînement:  97%|█████████▋| 9734/10000 [31:11<01:06,  3.98step/s, loss=0.032690, elapsed=31.2min]
# Entraînement:  97%|█████████▋| 9734/10000 [31:11<01:06,  3.98step/s, loss=0.038470, elapsed=31.2min]
# Entraînement:  97%|█████████▋| 9735/10000 [31:11<01:01,  4.30step/s, loss=0.038470, elapsed=31.2min]
# Entraînement:  97%|█████████▋| 9735/10000 [31:11<01:01,  4.30step/s, loss=0.056011, elapsed=31.2min]
# Entraînement:  97%|█████████▋| 9736/10000 [31:11<00:58,  4.55step/s, loss=0.056011, elapsed=31.2min]
# Entraînement:  97%|█████████▋| 9736/10000 [31:11<00:58,  4.55step/s, loss=0.066082, elapsed=31.2min]
# Entraînement:  97%|█████████▋| 9737/10000 [31:12<00:55,  4.75step/s, loss=0.066082, elapsed=31.2min]
# Entraînement:  97%|█████████▋| 9737/10000 [31:12<00:55,  4.75step/s, loss=0.041106, elapsed=31.2min]
# Entraînement:  97%|█████████▋| 9738/10000 [31:12<00:53,  4.89step/s, loss=0.041106, elapsed=31.2min]
# Entraînement:  97%|█████████▋| 9738/10000 [31:12<00:53,  4.89step/s, loss=0.051013, elapsed=31.2min]
# Entraînement:  97%|█████████▋| 9739/10000 [31:12<00:52,  4.99step/s, loss=0.051013, elapsed=31.2min]
# Entraînement:  97%|█████████▋| 9739/10000 [31:12<00:52,  4.99step/s, loss=0.051973, elapsed=31.2min]
# Entraînement:  97%|█████████▋| 9740/10000 [31:12<00:51,  5.06step/s, loss=0.051973, elapsed=31.2min]
# Entraînement:  97%|█████████▋| 9740/10000 [31:12<00:51,  5.06step/s, loss=0.069114, elapsed=31.2min]
# Entraînement:  97%|█████████▋| 9741/10000 [31:12<00:50,  5.12step/s, loss=0.069114, elapsed=31.2min]
# Entraînement:  97%|█████████▋| 9741/10000 [31:12<00:50,  5.12step/s, loss=0.014679, elapsed=31.2min]
# Entraînement:  97%|█████████▋| 9742/10000 [31:12<00:49,  5.18step/s, loss=0.014679, elapsed=31.2min]
# Entraînement:  97%|█████████▋| 9742/10000 [31:12<00:49,  5.18step/s, loss=0.021050, elapsed=31.2min]
# Entraînement:  97%|█████████▋| 9743/10000 [31:13<00:49,  5.21step/s, loss=0.021050, elapsed=31.2min]
# Entraînement:  97%|█████████▋| 9743/10000 [31:13<00:49,  5.21step/s, loss=0.046715, elapsed=31.2min]
# Entraînement:  97%|█████████▋| 9744/10000 [31:13<00:48,  5.23step/s, loss=0.046715, elapsed=31.2min]
# Entraînement:  97%|█████████▋| 9744/10000 [31:13<00:48,  5.23step/s, loss=0.047453, elapsed=31.2min]
# Entraînement:  97%|█████████▋| 9745/10000 [31:13<00:48,  5.25step/s, loss=0.047453, elapsed=31.2min]
# Entraînement:  97%|█████████▋| 9745/10000 [31:13<00:48,  5.25step/s, loss=0.038436, elapsed=31.2min]
# Entraînement:  97%|█████████▋| 9746/10000 [31:13<00:48,  5.25step/s, loss=0.038436, elapsed=31.2min]
# Entraînement:  97%|█████████▋| 9746/10000 [31:13<00:48,  5.25step/s, loss=0.037540, elapsed=31.2min]
# Entraînement:  97%|█████████▋| 9747/10000 [31:13<00:48,  5.21step/s, loss=0.037540, elapsed=31.2min]
# Entraînement:  97%|█████████▋| 9747/10000 [31:13<00:48,  5.21step/s, loss=0.050853, elapsed=31.2min]
# Entraînement:  97%|█████████▋| 9748/10000 [31:14<00:48,  5.24step/s, loss=0.050853, elapsed=31.2min]
# Entraînement:  97%|█████████▋| 9748/10000 [31:14<00:48,  5.24step/s, loss=0.097129, elapsed=31.2min]
# Entraînement:  97%|█████████▋| 9749/10000 [31:14<00:47,  5.25step/s, loss=0.097129, elapsed=31.2min]
# Entraînement:  97%|█████████▋| 9749/10000 [31:14<00:47,  5.25step/s, loss=0.024816, elapsed=31.2min]
# Entraînement:  98%|█████████▊| 9750/10000 [31:14<00:47,  5.26step/s, loss=0.024816, elapsed=31.2min]
# Entraînement:  98%|█████████▊| 9750/10000 [31:14<00:47,  5.26step/s, loss=0.047067, elapsed=31.2min]
# Entraînement:  98%|█████████▊| 9751/10000 [31:14<00:47,  5.28step/s, loss=0.047067, elapsed=31.2min]
# Entraînement:  98%|█████████▊| 9751/10000 [31:14<00:47,  5.28step/s, loss=0.074371, elapsed=31.2min]
# Entraînement:  98%|█████████▊| 9752/10000 [31:14<00:46,  5.28step/s, loss=0.074371, elapsed=31.2min]
# Entraînement:  98%|█████████▊| 9752/10000 [31:14<00:46,  5.28step/s, loss=0.040880, elapsed=31.2min]
# Entraînement:  98%|█████████▊| 9753/10000 [31:15<00:46,  5.28step/s, loss=0.040880, elapsed=31.2min]
# Entraînement:  98%|█████████▊| 9753/10000 [31:15<00:46,  5.28step/s, loss=0.030115, elapsed=31.3min]

# %%
final_checkpoint_path = EXPERIMENT_DIR / "final_checkpoint.pt"

torch.save({
    "step": global_step,
    "model_state_dict": model.state_dict(),
    "optimizer_state_dict": optimizer.state_dict(),
    "train_losses": train_losses,
    "val_losses": val_losses,
    "params": params.__dict__ if hasattr(params, "__dict__") else None,
    "summary": summary
}, final_checkpoint_path)

print("Checkpoint final sauvegardé ici :")
print(final_checkpoint_path)

# %%
loss_df = pd.DataFrame({
    "step": list(range(1, len(train_losses) + 1)),
    "train_loss": train_losses
})

loss_csv_path = RESULTS_DIR / "diffwave_training_losses.csv"
loss_df.to_csv(loss_csv_path, index=False)

plt.figure(figsize=(10, 5))
plt.plot(loss_df["step"], loss_df["train_loss"])
plt.xlabel("Step")
plt.ylabel("MSE Loss")
plt.title("Évolution de la loss d'entraînement")
plt.grid(True)
plt.show()

loss_fig_path = FIGURES_DIR / "diffwave_training_loss.png"

plt.figure(figsize=(10, 5))
plt.plot(loss_df["step"], loss_df["train_loss"])
plt.xlabel("Step")
plt.ylabel("MSE Loss")
plt.title("Évolution de la loss d'entraînement")
plt.grid(True)
plt.savefig(loss_fig_path, dpi=300, bbox_inches="tight")
plt.close()

print("Loss CSV sauvegardé :", loss_csv_path)
print("Figure sauvegardée :", loss_fig_path)

# %%
if len(val_losses) > 0:
    val_loss_df = pd.DataFrame(val_losses)

    val_loss_csv_path = RESULTS_DIR / "diffwave_validation_losses.csv"
    val_loss_df.to_csv(val_loss_csv_path, index=False)

    plt.figure(figsize=(10, 5))
    plt.plot(val_loss_df["step"], val_loss_df["val_loss"], marker="o")
    plt.xlabel("Step")
    plt.ylabel("Validation MSE Loss")
    plt.title("Évolution de la loss de validation")
    plt.grid(True)
    plt.show()

    val_loss_fig_path = FIGURES_DIR / "diffwave_validation_loss.png"

    plt.figure(figsize=(10, 5))
    plt.plot(val_loss_df["step"], val_loss_df["val_loss"], marker="o")
    plt.xlabel("Step")
    plt.ylabel("Validation MSE Loss")
    plt.title("Évolution de la loss de validation")
    plt.grid(True)
    plt.savefig(val_loss_fig_path, dpi=300, bbox_inches="tight")
    plt.close()

    print("Validation CSV sauvegardé :", val_loss_csv_path)
    print("Figure sauvegardée :", val_loss_fig_path)
else:
    print("Aucune validation enregistrée.")

# %% [markdown]
# # Fin de l'entraînement
#
# À ce stade, le modèle a été entraîné sur le dataset DODa prétraité.
#
# Les fichiers importants sauvegardés sont :
#
# - `best_checkpoint.pt` : meilleur modèle selon la validation ;
# - `last_checkpoint.pt` : dernier modèle sauvegardé pendant l’entraînement ;
# - `final_checkpoint.pt` : modèle final ;
# - courbes de loss pour le rapport.
#
# La prochaine étape sera la génération audio à partir d’un spectrogramme Mel du jeu de test.

# %% [markdown]
# # Génération audio avec le modèle DiffWave entraîné
#
# Dans cette partie, on utilise le modèle entraîné pour générer de l'audio à partir d'un spectrogramme Mel.
#
# Le principe est le suivant :
#
# 1. On charge le meilleur checkpoint sauvegardé pendant l'entraînement.
# 2. On prend un exemple du jeu de test.
# 3. On utilise son Mel spectrogram comme condition.
# 4. On part d'un bruit blanc aléatoire.
# 5. On applique progressivement le processus inverse de diffusion.
# 6. On obtient une waveform audio générée.
# 7. On compare l'audio généré avec l'audio original.

# %%
# Chargement du meilleur checkpoint entraîné

best_checkpoint_path = EXPERIMENT_DIR / "best_checkpoint.pt"
last_checkpoint_path = EXPERIMENT_DIR / "last_checkpoint.pt"
final_checkpoint_path = EXPERIMENT_DIR / "final_checkpoint.pt"

# On choisit le meilleur checkpoint disponible
if best_checkpoint_path.exists():
    checkpoint_path = best_checkpoint_path
elif final_checkpoint_path.exists():
    checkpoint_path = final_checkpoint_path
elif last_checkpoint_path.exists():
    checkpoint_path = last_checkpoint_path
else:
    checkpoint_path = None

if checkpoint_path is not None:
    checkpoint = torch.load(
        checkpoint_path,
        map_location=device,
        weights_only=False
    )

    model.load_state_dict(checkpoint["model_state_dict"])
    model.to(device)
    model.eval()

    print("Checkpoint chargé :", checkpoint_path)
    print("Step du checkpoint :", checkpoint.get("step", "inconnu"))

else:
    print("Aucun checkpoint trouvé.")
    print("Le modèle actuellement en mémoire sera utilisé.")
    model.eval()

# %% [markdown]
# ## Préparation du jeu de test
#
# On utilise maintenant `test.csv`, qui contient les exemples réservés à l’évaluation.
#
# Pour la génération, on a besoin :
#
# - du Mel spectrogram comme entrée du modèle ;
# - de l’audio original pour comparer avec l’audio généré.

# %%
test_dataset = DiffWaveDODaDataset(
    dataframe=test_df,
    wav_dir=WAV_DIR,
    mel_dir=MEL_DIR,
    sample_rate=summary["sample_rate"],
    hop_length=summary["hop_length"],
    crop_mel_frames=params.crop_mel_frames
)

test_loader = DataLoader(
    test_dataset,
    batch_size=1,
    shuffle=False,
    num_workers=0
)

print("Nombre d'exemples test :", len(test_dataset))

# %% [markdown]
# ## Fonction de génération
#
# La fonction suivante applique le processus inverse de diffusion.
#
# On part d’un bruit blanc aléatoire, puis le modèle prédit à chaque étape le bruit à retirer.
# À la fin du processus, on obtient un signal audio généré.

# %%
@torch.no_grad()
def p_sample(model, x, diffusion_step, mel):
    """
    Une étape de diffusion inverse.

    x doit avoir la shape [B, T].
    mel doit avoir la shape [B, 80, F].
    """

    # Sécurité : si x est [B, 1, T], on enlève la dimension inutile
    if x.dim() == 3:
        x = x.squeeze(1)

    batch_size = x.shape[0]

    t = torch.full(
        (batch_size,),
        diffusion_step,
        device=device,
        dtype=torch.long
    )

    predicted_noise = model(x, t, mel)

    # Sécurité : predicted_noise doit aussi être [B, T]
    if predicted_noise.dim() == 3:
        predicted_noise = predicted_noise.squeeze(1)

    beta_t = noise_schedule[diffusion_step]
    alpha_t = alphas[diffusion_step]
    alpha_cumprod_t = alpha_cumprod[diffusion_step]

    coef = beta_t / torch.sqrt(1.0 - alpha_cumprod_t)

    mean = (1.0 / torch.sqrt(alpha_t)) * (x - coef * predicted_noise)

    if diffusion_step > 0:
        noise = torch.randn_like(x)
        sigma = torch.sqrt(beta_t)
        x_prev = mean + sigma * noise
    else:
        x_prev = mean

    return x_prev


@torch.no_grad()
def generate_audio_from_mel(model, mel, audio_length):
    """
    Génère un audio à partir d'un Mel spectrogram.

    Le modèle DiffWave attend :
    - audio : [B, T]
    - mel : [B, 80, F]
    """

    model.eval()

    if mel.dim() == 2:
        mel = mel.unsqueeze(0)

    mel = mel.to(device)

    # Important : x doit être [B, T], pas [B, 1, T]
    x = torch.randn(
        mel.shape[0],
        audio_length,
        device=device
    )

    for step in tqdm(
        reversed(range(NUM_DIFFUSION_STEPS)),
        total=NUM_DIFFUSION_STEPS,
        desc="Génération"
    ):
        x = p_sample(model, x, step, mel)

    # Normalisation finale
    x = x / (x.abs().max(dim=1, keepdim=True)[0] + 1e-8)

    return x

# %% [markdown]
# ## Génération d’un premier exemple
#
# On sélectionne un exemple du jeu de test, puis on génère l’audio correspondant à partir de son Mel spectrogram.
#
# On pourra ensuite écouter :
#
# - l’audio original ;
# - l’audio généré.

# %%
# Récupération d'un exemple du jeu de test

test_batch = next(iter(test_loader))

original_audio = test_batch["audio"].to(device)
mel = test_batch["mel"].to(device)

example_id = test_batch["id"][0]
example_speaker = test_batch["speaker"][0]
example_text = test_batch["text_latin"][0]

audio_length = original_audio.shape[1]

print("ID :", example_id)
print("Speaker :", example_speaker)
print("Texte :", example_text)
print("Audio original shape :", original_audio.shape)
print("Mel shape :", mel.shape)
print("Longueur audio à générer :", audio_length)

# %%
generated_audio = generate_audio_from_mel(
    model=model,
    mel=mel,
    audio_length=audio_length
)

print("Audio généré shape :", generated_audio.shape)

# %% [markdown]
# ## Sauvegarde et écoute
#
# On sauvegarde l’audio généré au format `.wav`, puis on écoute l’original et le généré directement dans le notebook.

# %%
from IPython.display import Audio, display

GENERATED_DIR = PROJECT_DIR / "generated_audios"
GENERATED_DIR.mkdir(parents=True, exist_ok=True)

generated_audio_np = generated_audio[0].detach().cpu().numpy()
original_audio_np = original_audio[0].detach().cpu().numpy()

generated_audio_path = GENERATED_DIR / f"generated_{str(example_id).zfill(5)}.wav"

sf.write(
    generated_audio_path,
    generated_audio_np,
    summary["sample_rate"]
)

print("Audio généré sauvegardé ici :")
print(generated_audio_path)

# %%
print("Audio original :")
display(Audio(original_audio_np, rate=summary["sample_rate"]))

print("Audio généré :")
display(Audio(generated_audio_np, rate=summary["sample_rate"]))

# %% [markdown]
# ## Comparaison visuelle
#
# On compare maintenant l’audio original et l’audio généré sous forme de waveform.
#
# Cette visualisation permet de vérifier rapidement si le signal généré présente une structure ou s’il ressemble seulement à du bruit.

# %%
plt.figure(figsize=(12, 4))
plt.plot(original_audio_np, label="Original", alpha=0.8)
plt.plot(generated_audio_np, label="Généré", alpha=0.7)
plt.title(f"Waveform original vs généré — ID {example_id}")
plt.xlabel("Échantillons")
plt.ylabel("Amplitude")
plt.legend()
plt.grid(True)
plt.show()

waveform_comparison_path = FIGURES_DIR / f"waveform_original_vs_generated_{str(example_id).zfill(5)}.png"

plt.figure(figsize=(12, 4))
plt.plot(original_audio_np, label="Original", alpha=0.8)
plt.plot(generated_audio_np, label="Généré", alpha=0.7)
plt.title(f"Waveform original vs généré — ID {example_id}")
plt.xlabel("Échantillons")
plt.ylabel("Amplitude")
plt.legend()
plt.grid(True)
plt.savefig(waveform_comparison_path, dpi=300, bbox_inches="tight")
plt.close()

print("Figure sauvegardée ici :")
print(waveform_comparison_path)

# %% [markdown]
# ## Spectrogramme Mel de l’audio généré
#
# On calcule le Mel spectrogram de l’audio généré afin de le comparer visuellement avec le Mel utilisé comme condition.

# %%
generated_mel = librosa.feature.melspectrogram(
    y=generated_audio_np,
    sr=summary["sample_rate"],
    n_fft=summary["n_fft"],
    hop_length=summary["hop_length"],
    win_length=summary["n_fft"],
    n_mels=summary["n_mels"],
    power=1.0
)

generated_mel_log = np.log(np.clip(generated_mel, 1e-5, None))
generated_mel_log = np.clip(generated_mel_log, -11.5, None)

condition_mel = mel[0].detach().cpu().numpy()

fig, axes = plt.subplots(1, 2, figsize=(14, 4))

librosa.display.specshow(
    condition_mel,
    sr=summary["sample_rate"],
    hop_length=summary["hop_length"],
    x_axis="time",
    y_axis="mel",
    ax=axes[0]
)
axes[0].set_title("Mel conditionnel")

librosa.display.specshow(
    generated_mel_log,
    sr=summary["sample_rate"],
    hop_length=summary["hop_length"],
    x_axis="time",
    y_axis="mel",
    ax=axes[1]
)
axes[1].set_title("Mel de l'audio généré")

plt.suptitle(f"Comparaison Mel — ID {example_id}")
plt.tight_layout()
plt.show()

mel_comparison_path = FIGURES_DIR / f"mel_condition_vs_generated_{str(example_id).zfill(5)}.png"

fig, axes = plt.subplots(1, 2, figsize=(14, 4))

librosa.display.specshow(
    condition_mel,
    sr=summary["sample_rate"],
    hop_length=summary["hop_length"],
    x_axis="time",
    y_axis="mel",
    ax=axes[0]
)
axes[0].set_title("Mel conditionnel")

librosa.display.specshow(
    generated_mel_log,
    sr=summary["sample_rate"],
    hop_length=summary["hop_length"],
    x_axis="time",
    y_axis="mel",
    ax=axes[1]
)
axes[1].set_title("Mel de l'audio généré")

plt.suptitle(f"Comparaison Mel — ID {example_id}")
plt.tight_layout()
plt.savefig(mel_comparison_path, dpi=300, bbox_inches="tight")
plt.close()

print("Figure sauvegardée ici :")
print(mel_comparison_path)

# %% [markdown]
# ## Génération de plusieurs exemples
#
# On génère maintenant plusieurs audios à partir du jeu de test.
#
# Les résultats sont sauvegardés dans un dossier dédié et récapitulés dans un fichier CSV.

# %%
NUM_EXAMPLES_TO_GENERATE = 5

generated_results = []

model.eval()

for i in range(NUM_EXAMPLES_TO_GENERATE):
    sample = test_dataset[i]

    mel_i = sample["mel"].unsqueeze(0).to(device)
    original_audio_i = sample["audio"].unsqueeze(0).to(device)

    sample_id = str(sample["id"]).zfill(5)
    speaker = sample["speaker"]
    text = sample["text_latin"]

    audio_length_i = original_audio_i.shape[1]

    gen_audio_i = generate_audio_from_mel(
        model=model,
        mel=mel_i,
        audio_length=audio_length_i
    )

    gen_audio_np_i = gen_audio_i[0].detach().cpu().numpy()

    output_path = GENERATED_DIR / f"generated_{sample_id}.wav"

    sf.write(
        output_path,
        gen_audio_np_i,
        summary["sample_rate"]
    )

    generated_results.append({
        "id": sample_id,
        "speaker": speaker,
        "text_latin": text,
        "generated_audio_path": str(output_path)
    })

    print(f"Exemple {i+1}/{NUM_EXAMPLES_TO_GENERATE} généré :", output_path)

# %%
generated_results_df = pd.DataFrame(generated_results)

generated_results_path = RESULTS_DIR / "generated_audio_results.csv"
generated_results_df.to_csv(generated_results_path, index=False)

print("Résultats sauvegardés ici :")
print(generated_results_path)

display(generated_results_df)

# %%
for _, row in generated_results_df.iterrows():
    print("ID :", row["id"])
    print("Speaker :", row["speaker"])
    print("Texte :", row["text_latin"])
    display(Audio(row["generated_audio_path"], rate=summary["sample_rate"]))

# %% [markdown]
# ## Évaluation qualitative
#
# Les audios générés peuvent être évalués manuellement selon plusieurs critères :
#
# - qualité sonore générale ;
# - niveau de bruit ;
# - stabilité du signal ;
# - ressemblance avec une voix humaine ;
# - cohérence avec le Mel conditionnel.
#
# Si l’entraînement est court, il est normal que les audios soient encore bruités.
# Dans ce cas, l’objectif principal est de montrer que le pipeline complet fonctionne.

# %%
evaluation_df = pd.DataFrame({
    "id": generated_results_df["id"],
    "speaker": generated_results_df["speaker"],
    "quality_score_1_to_5": [None] * len(generated_results_df),
    "noise_level_1_to_5": [None] * len(generated_results_df),
    "voice_naturalness_1_to_5": [None] * len(generated_results_df),
    "comments": [None] * len(generated_results_df)
})

evaluation_path = RESULTS_DIR / "qualitative_evaluation_template.csv"
evaluation_df.to_csv(evaluation_path, index=False)

print("Template d'évaluation sauvegardé ici :")
print(evaluation_path)

display(evaluation_df)

# %% [markdown]
# # Fin de la génération audio
#
# À ce stade, le pipeline complet est réalisé :
#
# 1. données prétraitées ;
# 2. Dataset PyTorch ;
# 3. modèle DiffWave ;
# 4. entraînement ;
# 5. sauvegarde du checkpoint ;
# 6. génération audio ;
# 7. comparaison original / généré ;
# 8. préparation de l’évaluation qualitative.
#
# Les résultats générés peuvent maintenant être utilisés dans le rapport et la présentation.
